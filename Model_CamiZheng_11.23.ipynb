# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from surprise import SVD, Dataset, Reader, accuracy
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import nltk


nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/camellia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/camellia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load datasets
investors_df = pd.read_csv('cleaned_openvc.csv')
ideas_df = pd.read_csv('cleaned_ideas.csv')

# Fill NaN values with an empty string
ideas_df['idea_description'] = ideas_df['idea_description'].fillna("")
investors_df['Investment thesis'] = investors_df['Investment thesis'].fillna("")

# Preprocess the text
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    words = text.lower().split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # Lemmatize and remove stopwords
    return words

investment_sentences = investors_df['Investment thesis'].apply(preprocess_text).tolist()
idea_sentences = ideas_df['idea_description'].apply(preprocess_text).tolist()

# %%
all_sentences = investment_sentences + idea_sentences
model = Word2Vec(sentences=all_sentences, vector_size=200, window=10, min_count=5, workers=4)

# %%
def compute_text_embedding(text, model):
    words = preprocess_text(text)
    valid_words = [model.wv[word] for word in words if word in model.wv]
    if valid_words:
        return np.mean(valid_words, axis=0)
    else:
        return np.zeros(model.vector_size)

investors_df['embedding'] = investors_df['Investment thesis'].apply(lambda x: compute_text_embedding(x, model))
ideas_df['embedding'] = ideas_df['idea_description'].apply(lambda x: compute_text_embedding(x, model))

# %%
def encode_and_combine(df, columns):
    encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')
    encoded = encoder.fit_transform(df[columns])
    return pd.DataFrame(encoded, index=df.index)

investors_categoricals = encode_and_combine(investors_df, ['Countries of investment', 'Stage of investment', 'Investor type'])
ideas_categoricals = encode_and_combine(ideas_df, ['user_last_ip_country_name'])
# Out:
# /Users/camellia/anaconda3/envs/class/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# /Users/camellia/anaconda3/envs/class/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
investors_features = pd.concat([investors_categoricals, investors_df['embedding'].apply(pd.Series)], axis=1)
ideas_features = pd.concat([ideas_categoricals, ideas_df['embedding'].apply(pd.Series)], axis=1)

# Align feature dimensions and scale
investors_features_aligned, ideas_features_aligned = investors_features.align(ideas_features, fill_value=0, axis=1)
scaler = StandardScaler()
investors_features_scaled = scaler.fit_transform(investors_features_aligned)
ideas_features_scaled = scaler.transform(ideas_features_aligned)

# %%
cosine_similarities = cosine_similarity(ideas_features_scaled, investors_features_scaled)
cosine_similarity_df = pd.DataFrame(cosine_similarities, columns=investors_df['Investor name'], index=ideas_df['idea_description'])
print(cosine_similarity_df)
# Out:
# Investor name                                       3TS Capital Partners  \
# idea_description
# An organizer system that you install in handbag...              0.013594
# A business that does balloon animals for corpor...              0.020915
#                                                                 0.096432
# I'm building a global innovation platform that ...             -0.003038
# sharikat tasnae eilajat lilkilab khaliatan min ...              0.029023
# A company that makes an app to stop food waste ...             -0.005685
# a business for tourists that uses a QR code to ...              0.002885
# A lemonade stand outside event venues to sell t...              0.031271
# A mems small satellite propulsion system for ma...             -0.005138
# BlockLenses are UV blocking daily-wear contact ...              0.029946
# Mainstream air transportation with low carbon e...              0.037637
# Digital marketplace for electric vehicles to ma...              0.020659
# A business that uses AI to train screenwriters ...             -0.002239
# A business that produces onion seeds in Guatema...              0.004063
# A cross-border payment processor for money tran...              0.028580
# How do I take a media company that has a follow...              0.005451
# une entreprise qui fabrique des friandises pour...              0.039343
# A fintech company that uses AI and big data to ...             -0.001119
# A platform that connects startups and investors                -0.029989
# A AIrbnb-like business that allows older people...              0.010422
# A company that is measuring noise through consu...             -0.010260
# A medical device company that tracks sleep.                    -0.004977
# A software learning platform to upskill develop...             -0.015445
#
# Investor name                                            3VC  \
# idea_description
# An organizer system that you install in handbag... -0.022992
# A business that does balloon animals for corpor... -0.025053
#                                                    -0.059871
# I'm building a global innovation platform that ... -0.018104
# sharikat tasnae eilajat lilkilab khaliatan min ... -0.027654
# A company that makes an app to stop food waste ... -0.016991
# a business for tourists that uses a QR code to ... -0.019769
# A lemonade stand outside event venues to sell t... -0.028100
# A mems small satellite propulsion system for ma... -0.017144
# BlockLenses are UV blocking daily-wear contact ... -0.027845
# Mainstream air transportation with low carbon e... -0.029692
# Digital marketplace for electric vehicles to ma... -0.025174
# A business that uses AI to train screenwriters ... -0.017952
# A business that produces onion seeds in Guatema... -0.020404
# A cross-border payment processor for money tran... -0.027537
# How do I take a media company that has a follow... -0.020389
# une entreprise qui fabrique des friandises pour... -0.030431
# A fintech company that uses AI and big data to ... -0.018875
# A platform that connects startups and investors    -0.008890
# A AIrbnb-like business that allows older people... -0.022220
# A company that is measuring noise through consu... -0.016127
# A medical device company that tracks sleep.        -0.017440
# A software learning platform to upskill develop... -0.013405
#
# Investor name                                       7percent Ventures  \
# idea_description
# An organizer system that you install in handbag...           0.020278
# A business that does balloon animals for corpor...           0.028146
#                                                              0.098618
# I'm building a global innovation platform that ...           0.002908
# sharikat tasnae eilajat lilkilab khaliatan min ...           0.036651
# A company that makes an app to stop food waste ...          -0.000072
# a business for tourists that uses a QR code to ...           0.008943
# A lemonade stand outside event venues to sell t...           0.039077
# A mems small satellite propulsion system for ma...           0.000196
# BlockLenses are UV blocking daily-wear contact ...           0.037690
# Mainstream air transportation with low carbon e...           0.045838
# Digital marketplace for electric vehicles to ma...           0.027586
# A business that uses AI to train screenwriters ...           0.003336
# A business that produces onion seeds in Guatema...           0.010621
# A cross-border payment processor for money tran...           0.036043
# How do I take a media company that has a follow...           0.011698
# une entreprise qui fabrique des friandises pour...           0.047512
# A fintech company that uses AI and big data to ...           0.004608
# A platform that connects startups and investors             -0.025830
# A AIrbnb-like business that allows older people...           0.017084
# A company that is measuring noise through consu...          -0.005321
# A medical device company that tracks sleep.                  0.000288
# A software learning platform to upskill develop...          -0.010769
#
# Investor name                                       10K Ventures  \
# idea_description
# An organizer system that you install in handbag...      0.014110
# A business that does balloon animals for corpor...      0.020549
#                                                         0.075322
# I'm building a global innovation platform that ...      0.000623
# sharikat tasnae eilajat lilkilab khaliatan min ...      0.027609
# A company that makes an app to stop food waste ...     -0.002036
# a business for tourists that uses a QR code to ...      0.005129
# A lemonade stand outside event venues to sell t...      0.029357
# A mems small satellite propulsion system for ma...     -0.001756
# BlockLenses are UV blocking daily-wear contact ...      0.028642
# Mainstream air transportation with low carbon e...      0.034908
# Digital marketplace for electric vehicles to ma...      0.020101
# A business that uses AI to train screenwriters ...      0.000433
# A business that produces onion seeds in Guatema...      0.006917
# A cross-border payment processor for money tran...      0.027089
# How do I take a media company that has a follow...      0.007324
# une entreprise qui fabrique des friandises pour...      0.036641
# A fintech company that uses AI and big data to ...      0.001825
# A platform that connects startups and investors        -0.022314
# A AIrbnb-like business that allows older people...      0.011864
# A company that is measuring noise through consu...     -0.006143
# A medical device company that tracks sleep.            -0.001558
# A software learning platform to upskill develop...     -0.010670
#
# Investor name                                       27V (Twenty Seven Ventures)  \
# idea_description
# An organizer system that you install in handbag...                     0.014074
# A business that does balloon animals for corpor...                     0.015769
#                                                                        0.008903
# I'm building a global innovation platform that ...                     0.010820
# sharikat tasnae eilajat lilkilab khaliatan min ...                     0.017028
# A company that makes an app to stop food waste ...                     0.009978
# a business for tourists that uses a QR code to ...                     0.011834
# A lemonade stand outside event venues to sell t...                     0.017748
# A mems small satellite propulsion system for ma...                     0.010112
# BlockLenses are UV blocking daily-wear contact ...                     0.017628
# Mainstream air transportation with low carbon e...                     0.019227
# Digital marketplace for electric vehicles to ma...                     0.015349
# A business that uses AI to train screenwriters ...                     0.010481
# A business that produces onion seeds in Guatema...                     0.012645
# A cross-border payment processor for money tran...                     0.017145
# How do I take a media company that has a follow...                     0.012537
# une entreprise qui fabrique des friandises pour...                     0.019287
# A fintech company that uses AI and big data to ...                     0.010964
# A platform that connects startups and investors                        0.004532
# A AIrbnb-like business that allows older people...                     0.013812
# A company that is measuring noise through consu...                     0.009015
# A medical device company that tracks sleep.                            0.009979
# A software learning platform to upskill develop...                     0.007527
#
# Investor name                                       50 Partners Capital  \
# idea_description
# An organizer system that you install in handbag...            -0.066279
# A business that does balloon animals for corpor...            -0.109650
#                                                               -0.590132
# I'm building a global innovation platform that ...             0.029818
# sharikat tasnae eilajat lilkilab khaliatan min ...            -0.158510
# A company that makes an app to stop food waste ...             0.047447
# a business for tourists that uses a QR code to ...            -0.003588
# A lemonade stand outside event venues to sell t...            -0.171239
# A mems small satellite propulsion system for ma...             0.044077
# BlockLenses are UV blocking daily-wear contact ...            -0.166036
# Mainstream air transportation with low carbon e...            -0.211295
# Digital marketplace for electric vehicles to ma...            -0.111319
# A business that uses AI to train screenwriters ...             0.026911
# A business that produces onion seeds in Guatema...            -0.012884
# A cross-border payment processor for money tran...            -0.157384
# How do I take a media company that has a follow...            -0.018890
# une entreprise qui fabrique des friandises pour...            -0.221714
# A fintech company that uses AI and big data to ...             0.017853
# A platform that connects startups and investors                0.186720
# A AIrbnb-like business that allows older people...            -0.049013
# A company that is measuring noise through consu...             0.072038
# A medical device company that tracks sleep.                    0.042840
# A software learning platform to upskill develop...             0.103898
#
# Investor name                                            212  212Founders  \
# idea_description
# An organizer system that you install in handbag... -0.019011    -0.000672
# A business that does balloon animals for corpor... -0.029816    -0.000052
#                                                    -0.138408     0.002004
# I'm building a global innovation platform that ...  0.004317    -0.001348
# sharikat tasnae eilajat lilkilab khaliatan min ... -0.041494     0.001075
# A company that makes an app to stop food waste ...  0.008457    -0.001892
# a business for tourists that uses a QR code to ... -0.003790    -0.001309
# A lemonade stand outside event venues to sell t... -0.044590     0.000807
# A mems small satellite propulsion system for ma...  0.007869    -0.002267
# BlockLenses are UV blocking daily-wear contact ... -0.042837     0.001201
# Mainstream air transportation with low carbon e... -0.053777     0.001750
# Digital marketplace for electric vehicles to ma... -0.029612     0.000067
# A business that uses AI to train screenwriters ...  0.003589    -0.001920
# A business that produces onion seeds in Guatema... -0.005950    -0.000688
# A cross-border payment processor for money tran... -0.040865     0.000795
# How do I take a media company that has a follow... -0.007612    -0.001151
# une entreprise qui fabrique des friandises pour... -0.056508     0.001956
# A fintech company that uses AI and big data to ...  0.001797    -0.001597
# A platform that connects startups and investors     0.042521    -0.002949
# A AIrbnb-like business that allows older people... -0.014771    -0.000482
# A company that is measuring noise through consu...  0.014491    -0.002527
# A medical device company that tracks sleep.         0.007289    -0.002081
# A software learning platform to upskill develop...  0.022503    -0.002808
#
# Investor name                                       360 Capital  365.fintech  \
# idea_description
# An organizer system that you install in handbag...    -0.013899     0.017966
# A business that does balloon animals for corpor...    -0.021599     0.029112
#                                                       -0.099270     0.149022
# I'm building a global innovation platform that ...     0.003167    -0.006267
# sharikat tasnae eilajat lilkilab khaliatan min ...    -0.029756     0.041317
# A company that makes an app to stop food waste ...     0.005819    -0.010635
# a business for tourists that uses a QR code to ...    -0.002865     0.002145
# A lemonade stand outside event venues to sell t...    -0.032197     0.044610
# A mems small satellite propulsion system for ma...     0.005558    -0.009704
# BlockLenses are UV blocking daily-wear contact ...    -0.030483     0.043133
# Mainstream air transportation with low carbon e...    -0.038438     0.054435
# Digital marketplace for electric vehicles to ma...    -0.020737     0.029203
# A business that uses AI to train screenwriters ...     0.002536    -0.005557
# A business that produces onion seeds in Guatema...    -0.004343     0.004407
# A cross-border payment processor for money tran...    -0.028972     0.041056
# How do I take a media company that has a follow...    -0.005503     0.005995
# une entreprise qui fabrique des friandises pour...    -0.040212     0.057358
# A fintech company that uses AI and big data to ...     0.001504    -0.003155
# A platform that connects startups and investors        0.030725    -0.046011
# A AIrbnb-like business that allows older people...    -0.010540     0.013679
# A company that is measuring noise through consu...     0.010993    -0.016721
# A medical device company that tracks sleep.            0.005633    -0.009295
# A software learning platform to upskill develop...     0.016074    -0.025008
#
# Investor name                                       ...  Far Out Ventures  \
# idea_description                                    ...
# An organizer system that you install in handbag...  ...          0.033423
# A business that does balloon animals for corpor...  ...          0.049887
#                                                     ...          0.207961
# I'm building a global innovation platform that ...  ...         -0.002621
# sharikat tasnae eilajat lilkilab khaliatan min ...  ...          0.067949
# A company that makes an app to stop food waste ...  ...         -0.009004
# a business for tourists that uses a QR code to ...  ...          0.009807
# A lemonade stand outside event venues to sell t...  ...          0.072853
# A mems small satellite propulsion system for ma...  ...         -0.008110
# BlockLenses are UV blocking daily-wear contact ...  ...          0.070401
# Mainstream air transportation with low carbon e...  ...          0.087073
# Digital marketplace for electric vehicles to ma...  ...          0.049162
# A business that uses AI to train screenwriters ...  ...         -0.001977
# A business that produces onion seeds in Guatema...  ...          0.013625
# A cross-border payment processor for money tran...  ...          0.066875
# How do I take a media company that has a follow...  ...          0.015585
# une entreprise qui fabrique des friandises pour...  ...          0.091174
# A fintech company that uses AI and big data to ...  ...          0.001300
# A platform that connects startups and investors     ...         -0.062150
# A AIrbnb-like business that allows older people...  ...          0.026981
# A company that is measuring noise through consu...  ...         -0.019203
# A medical device company that tracks sleep.         ...         -0.007736
# A software learning platform to upskill develop...  ...         -0.030976
#
# Investor name                                       CivilizationX  \
# idea_description
# An organizer system that you install in handbag...       0.023144
# A business that does balloon animals for corpor...       0.034339
#                                                          0.146531
# I'm building a global innovation platform that ...      -0.001881
# sharikat tasnae eilajat lilkilab khaliatan min ...       0.046495
# A company that makes an app to stop food waste ...      -0.005956
# a business for tourists that uses a QR code to ...       0.006904
# A lemonade stand outside event venues to sell t...       0.050007
# A mems small satellite propulsion system for ma...      -0.005097
# BlockLenses are UV blocking daily-wear contact ...       0.047992
# Mainstream air transportation with low carbon e...       0.059522
# Digital marketplace for electric vehicles to ma...       0.033836
# A business that uses AI to train screenwriters ...      -0.000948
# A business that produces onion seeds in Guatema...       0.008958
# A cross-border payment processor for money tran...       0.045748
# How do I take a media company that has a follow...       0.010729
# une entreprise qui fabrique des friandises pour...       0.062241
# A fintech company that uses AI and big data to ...       0.001050
# A platform that connects startups and investors         -0.042830
# A AIrbnb-like business that allows older people...       0.018430
# A company that is measuring noise through consu...      -0.013064
# A medical device company that tracks sleep.             -0.005073
# A software learning platform to upskill develop...      -0.020740
#
# Investor name                                       VI Partners  \
# idea_description
# An organizer system that you install in handbag...    -0.076475
# A business that does balloon animals for corpor...    -0.100949
#                                                       -0.370483
# I'm building a global innovation platform that ...    -0.022279
# sharikat tasnae eilajat lilkilab khaliatan min ...    -0.128212
# A company that makes an app to stop food waste ...    -0.012294
# a business for tourists that uses a QR code to ...    -0.040946
# A lemonade stand outside event venues to sell t...    -0.134688
# A mems small satellite propulsion system for ma...    -0.014169
# BlockLenses are UV blocking daily-wear contact ...    -0.131631
# Mainstream air transportation with low carbon e...    -0.156189
# Digital marketplace for electric vehicles to ma...    -0.100512
# A business that uses AI to train screenwriters ...    -0.023219
# A business that produces onion seeds in Guatema...    -0.046554
# A cross-border payment processor for money tran...    -0.126922
# How do I take a media company that has a follow...    -0.050034
# une entreprise qui fabrique des friandises pour...    -0.162146
# A fintech company that uses AI and big data to ...    -0.028399
# A platform that connects startups and investors        0.068031
# A AIrbnb-like business that allows older people...    -0.066669
# A company that is measuring noise through consu...     0.002237
# A medical device company that tracks sleep.           -0.014512
# A software learning platform to upskill develop...     0.020913
#
# Investor name                                       Ecostar Capital  \
# idea_description
# An organizer system that you install in handbag...        -0.067356
# A business that does balloon animals for corpor...        -0.090611
#                                                           -0.262070
# I'm building a global innovation platform that ...        -0.015607
# sharikat tasnae eilajat lilkilab khaliatan min ...        -0.119966
# A company that makes an app to stop food waste ...        -0.007077
# a business for tourists that uses a QR code to ...        -0.032332
# A lemonade stand outside event venues to sell t...        -0.123816
# A mems small satellite propulsion system for ma...        -0.006876
# BlockLenses are UV blocking daily-wear contact ...        -0.121724
# Mainstream air transportation with low carbon e...        -0.144290
# Digital marketplace for electric vehicles to ma...        -0.085544
# A business that uses AI to train screenwriters ...        -0.012350
# A business that produces onion seeds in Guatema...        -0.040530
# A cross-border payment processor for money tran...        -0.114434
# How do I take a media company that has a follow...        -0.040774
# une entreprise qui fabrique des friandises pour...        -0.151168
# A fintech company that uses AI and big data to ...        -0.018503
# A platform that connects startups and investors            0.074711
# A AIrbnb-like business that allows older people...        -0.059269
# A company that is measuring noise through consu...         0.014262
# A medical device company that tracks sleep.               -0.007003
# A software learning platform to upskill develop...         0.027994
#
# Investor name                                       White Rhino Ventures  \
# idea_description
# An organizer system that you install in handbag...              0.037979
# A business that does balloon animals for corpor...              0.064622
#                                                                 0.344799
# I'm building a global innovation platform that ...             -0.020114
# sharikat tasnae eilajat lilkilab khaliatan min ...              0.090535
# A company that makes an app to stop food waste ...             -0.029923
# a business for tourists that uses a QR code to ...              0.001068
# A lemonade stand outside event venues to sell t...              0.100549
# A mems small satellite propulsion system for ma...             -0.028136
# BlockLenses are UV blocking daily-wear contact ...              0.094924
# Mainstream air transportation with low carbon e...              0.123354
# Digital marketplace for electric vehicles to ma...              0.065026
# A business that uses AI to train screenwriters ...             -0.014890
# A business that produces onion seeds in Guatema...              0.003856
# A cross-border payment processor for money tran...              0.090314
# How do I take a media company that has a follow...              0.009701
# une entreprise qui fabrique des friandises pour...              0.127611
# A fintech company that uses AI and big data to ...             -0.013187
# A platform that connects startups and investors                -0.111662
# A AIrbnb-like business that allows older people...              0.026434
# A company that is measuring noise through consu...             -0.044000
# A medical device company that tracks sleep.                    -0.027694
# A software learning platform to upskill develop...             -0.062622
#
# Investor name                                       GoodSoil VC  \
# idea_description
# An organizer system that you install in handbag...     0.000911
# A business that does balloon animals for corpor...     0.004951
#                                                        0.060568
# I'm building a global innovation platform that ...    -0.008153
# sharikat tasnae eilajat lilkilab khaliatan min ...     0.009037
# A company that makes an app to stop food waste ...    -0.009757
# a business for tourists that uses a QR code to ...    -0.004933
# A lemonade stand outside event venues to sell t...     0.010621
# A mems small satellite propulsion system for ma...    -0.009285
# BlockLenses are UV blocking daily-wear contact ...     0.009833
# Mainstream air transportation with low carbon e...     0.014367
# Digital marketplace for electric vehicles to ma...     0.005089
# A business that uses AI to train screenwriters ...    -0.007536
# A business that produces onion seeds in Guatema...    -0.004307
# A cross-border payment processor for money tran...     0.009190
# How do I take a media company that has a follow...    -0.003552
# une entreprise qui fabrique des friandises pour...     0.015048
# A fintech company that uses AI and big data to ...    -0.006893
# A platform that connects startups and investors       -0.022237
# A AIrbnb-like business that allows older people...    -0.000972
# A company that is measuring noise through consu...    -0.011651
# A medical device company that tracks sleep.           -0.009454
# A software learning platform to upskill develop...    -0.014642
#
# Investor name                                       Nucleus Capital     BK-XL  \
# idea_description
# An organizer system that you install in handbag...        -0.018901 -0.062664
# A business that does balloon animals for corpor...        -0.028304 -0.093367
#                                                           -0.127066 -0.409588
# I'm building a global innovation platform that ...         0.001667  0.004629
# sharikat tasnae eilajat lilkilab khaliatan min ...        -0.038194 -0.126055
# A company that makes an app to stop food waste ...         0.005240  0.017251
# a business for tourists that uses a QR code to ...        -0.005666 -0.019381
# A lemonade stand outside event venues to sell t...        -0.041208 -0.136009
# A mems small satellite propulsion system for ma...         0.004470  0.013845
# BlockLenses are UV blocking daily-wear contact ...        -0.039533 -0.131797
# Mainstream air transportation with low carbon e...        -0.049180 -0.163742
# Digital marketplace for electric vehicles to ma...        -0.028485 -0.095439
# A business that uses AI to train screenwriters ...         0.000439  0.001123
# A business that produces onion seeds in Guatema...        -0.007158 -0.024870
# A cross-border payment processor for money tran...        -0.037985 -0.127299
# How do I take a media company that has a follow...        -0.008995 -0.030408
# une entreprise qui fabrique des friandises pour...        -0.051377 -0.170619
# A fintech company that uses AI and big data to ...        -0.000865 -0.004535
# A platform that connects startups and investors            0.035033  0.114132
# A AIrbnb-like business that allows older people...        -0.015135 -0.050962
# A company that is measuring noise through consu...         0.010079  0.030550
# A medical device company that tracks sleep.                0.003983  0.012172
# A software learning platform to upskill develop...         0.017275  0.056476
#
# Investor name                                       Ben Padnos  Colin Howes
# idea_description
# An organizer system that you install in handbag...   -0.057104     0.080604
# A business that does balloon animals for corpor...   -0.098648     0.120968
#                                                      -0.562282     0.502674
# I'm building a global innovation platform that ...    0.035496    -0.005973
# sharikat tasnae eilajat lilkilab khaliatan min ...   -0.145842     0.164027
# A company that makes an app to stop food waste ...    0.051011    -0.021875
# a business for tourists that uses a QR code to ...    0.002552     0.023718
# A lemonade stand outside event venues to sell t...   -0.157269     0.176313
# A mems small satellite propulsion system for ma...    0.047515    -0.019694
# BlockLenses are UV blocking daily-wear contact ...   -0.150617     0.170146
# Mainstream air transportation with low carbon e...   -0.194123     0.210663
# Digital marketplace for electric vehicles to ma...   -0.099842     0.118502
# A business that uses AI to train screenwriters ...    0.030943    -0.005046
# A business that produces onion seeds in Guatema...   -0.003734     0.033752
# A cross-border payment processor for money tran...   -0.144358     0.161601
# How do I take a media company that has a follow...   -0.012177     0.037719
# une entreprise qui fabrique des friandises pour...   -0.204649     0.220360
# A fintech company that uses AI and big data to ...    0.024130     0.003349
# A platform that connects startups and investors       0.184781    -0.149452
# A AIrbnb-like business that allows older people...   -0.039996     0.065226
# A company that is measuring noise through consu...    0.073484    -0.046211
# A medical device company that tracks sleep.           0.045242    -0.019084
# A software learning platform to upskill develop...    0.105158    -0.074900
#
# [23 rows x 1960 columns]

# %%
interaction_data_melted = cosine_similarity_df.reset_index().melt(id_vars='idea_description', 
                                                                  var_name='Investor name', 
                                                                  value_name='cosine_similarity')

reader = Reader(rating_scale=(0, 1))
data = Dataset.load_from_df(interaction_data_melted[['idea_description', 'Investor name', 'cosine_similarity']], reader)

trainset, testset = train_test_split(data, test_size=0.2)
model = SVD()
model.fit(trainset)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 5
#       1 interaction_data_melted = cosine_similarity_df.reset_index().melt(id_vars='idea_description',
#       2                                                                   var_name='Investor name',
#       3                                                                   value_name='cosine_similarity')
# ----> 5 reader = Reader(rating_scale=(0, 1))
#       6 data = Dataset.load_from_df(interaction_data_melted[['idea_description', 'Investor name', 'cosine_similarity']], reader)
#       8 trainset, testset = train_test_split(data, test_size=0.2)
#
# NameError: name 'Reader' is not defined

# %%
def get_top_n_recommendations(predictions, n=5):
    top_n = {}
    for uid, iid, true_r, est, _ in predictions:
        if uid not in top_n:
            top_n[uid] = []
        top_n[uid].append((iid, est))
    
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
    
    return top_n

top_n_recommendations = get_top_n_recommendations(predictions, n=5)
for idea, recommendations in top_n_recommendations.items():
    print(f"Recommended investors for the idea: '{idea}'")
    for investor, rating in recommendations:
        print(f"  - {investor} (predicted similarity: {rating:.2f})")
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 14
#      10         top_n[uid] = user_ratings[:n]
#      12     return top_n
# ---> 14 top_n_recommendations = get_top_n_recommendations(predictions, n=5)
#      15 for idea, recommendations in top_n_recommendations.items():
#      16     print(f"Recommended investors for the idea: '{idea}'")
#
# NameError: name 'predictions' is not defined

# %%
from sklearn.cluster import MiniBatchKMeans

# Define number of clusters
n_clusters = 10

# Cluster investors and ideas
kmeans_investors = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
investors_clusters = kmeans_investors.fit_predict(investors_features_scaled)

kmeans_ideas = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
ideas_clusters = kmeans_ideas.fit_predict(ideas_features_scaled)

# Add cluster labels to DataFrames
investors_df['cluster'] = investors_clusters
ideas_df['cluster'] = ideas_clusters

# Recommend VCs within the same cluster as the idea
def recommend_vcs_within_cluster(idea_index, investors_df, ideas_df, n=5):
    idea_cluster = ideas_df.iloc[idea_index]['cluster']
    same_cluster_vcs = investors_df[investors_df['cluster'] == idea_cluster]
    
    # Rank VCs within the same cluster by similarity score
    similarities = cosine_similarities[idea_index, same_cluster_vcs.index]
    sorted_indices = np.argsort(similarities)[::-1][:n]
    return same_cluster_vcs.iloc[sorted_indices]['Investor name'].tolist()

# Example: Recommendations for the first idea
idea_index = 0
recommended_vcs = recommend_vcs_within_cluster(idea_index, investors_df, ideas_df, n=5)
print(f"Recommended VCs for idea '{ideas_df.iloc[idea_index]['idea_description']}':")
print(recommended_vcs)
# Out:
# /Users/camellia/anaconda3/envs/class/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Recommended VCs for idea 'An organizer system that you install in handbags to make it easier and faster to find things.':
# ['SuperSeed']
# /Users/camellia/anaconda3/envs/class/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
