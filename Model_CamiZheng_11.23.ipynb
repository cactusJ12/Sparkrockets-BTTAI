# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from surprise import SVD, Dataset, Reader, accuracy
from surprise.model_selection import train_test_split
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import nltk


nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\one_w\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\one_w\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load datasets
investors_df = pd.read_csv('cleaned_openvc.csv')
ideas_df = pd.read_csv('cleaned_ideas.csv')

# Fill NaN values with an empty string
ideas_df['idea_description'] = ideas_df['idea_description'].fillna("")
investors_df['Investment thesis'] = investors_df['Investment thesis'].fillna("")

# Preprocess the text
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    words = text.lower().split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # Lemmatize and remove stopwords
    return words

investment_sentences = investors_df['Investment thesis'].apply(preprocess_text).tolist()
idea_sentences = ideas_df['idea_description'].apply(preprocess_text).tolist()

# %%
all_sentences = investment_sentences + idea_sentences
model = Word2Vec(sentences=all_sentences, vector_size=200, window=10, min_count=5, workers=4)

# %%
def compute_text_embedding(text, model):
    words = preprocess_text(text)
    valid_words = [model.wv[word] for word in words if word in model.wv]
    if valid_words:
        return np.mean(valid_words, axis=0)
    else:
        return np.zeros(model.vector_size)

investors_df['embedding'] = investors_df['Investment thesis'].apply(lambda x: compute_text_embedding(x, model))
ideas_df['embedding'] = ideas_df['idea_description'].apply(lambda x: compute_text_embedding(x, model))

# %%
def encode_and_combine(df, columns):
    encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    encoded = encoder.fit_transform(df[columns])
    return pd.DataFrame(encoded, index=df.index)

investors_categoricals = encode_and_combine(investors_df, ['Countries of investment', 'Stage of investment', 'Investor type'])
ideas_categoricals = encode_and_combine(ideas_df, ['user_last_ip_country_name'])

# %%
investors_features = pd.concat([investors_categoricals, investors_df['embedding'].apply(pd.Series)], axis=1)
ideas_features = pd.concat([ideas_categoricals, ideas_df['embedding'].apply(pd.Series)], axis=1)

# Align feature dimensions and scale
investors_features_aligned, ideas_features_aligned = investors_features.align(ideas_features, fill_value=0, axis=1)
scaler = StandardScaler()
investors_features_scaled = scaler.fit_transform(investors_features_aligned)
ideas_features_scaled = scaler.transform(ideas_features_aligned)

# %%
cosine_similarities = cosine_similarity(ideas_features_scaled, investors_features_scaled)
cosine_similarity_df = pd.DataFrame(cosine_similarities, columns=investors_df['Investor name'], index=ideas_df['idea_description'])
print(cosine_similarity_df)
# Out:
# Investor name                                       3TS Capital Partners  \
# idea_description
# An organizer system that you install in handbag...              0.010556
# A business that does balloon animals for corpor...              0.014371
#                                                                 0.100021
# I'm building a global innovation platform that ...             -0.001779
# sharikat tasnae eilajat lilkilab khaliatan min ...              0.021133
# A company that makes an app to stop food waste ...             -0.002464
# a business for tourists that uses a QR code to ...              0.002383
# A lemonade stand outside event venues to sell t...              0.018985
# A mems small satellite propulsion system for ma...             -0.000328
# BlockLenses are UV blocking daily-wear contact ...              0.021778
# Mainstream air transportation with low carbon e...              0.025294
# Digital marketplace for electric vehicles to ma...              0.015266
# A business that uses AI to train screenwriters ...             -0.000291
# A business that produces onion seeds in Guatema...              0.004702
# A cross-border payment processor for money tran...              0.018779
# How do I take a media company that has a follow...              0.003825
# une entreprise qui fabrique des friandises pour...              0.026641
# A fintech company that uses AI and big data to ...              0.000531
# A platform that connects startups and investors                -0.022282
# A AIrbnb-like business that allows older people...              0.009332
# A company that is measuring noise through consu...             -0.007176
# A medical device company that tracks sleep.                    -0.002462
# A software learning platform to upskill develop...             -0.009280
#
# Investor name                                            3VC  \
# idea_description
# An organizer system that you install in handbag... -0.006562
# A business that does balloon animals for corpor... -0.008444
#                                                    -0.056011
# I'm building a global innovation platform that ... -0.002459
# sharikat tasnae eilajat lilkilab khaliatan min ... -0.010857
# A company that makes an app to stop food waste ... -0.002079
# a business for tourists that uses a QR code to ... -0.003977
# A lemonade stand outside event venues to sell t... -0.010143
# A mems small satellite propulsion system for ma... -0.002658
# BlockLenses are UV blocking daily-wear contact ... -0.010963
# Mainstream air transportation with low carbon e... -0.011897
# Digital marketplace for electric vehicles to ma... -0.008446
# A business that uses AI to train screenwriters ... -0.002681
# A business that produces onion seeds in Guatema... -0.005119
# A cross-border payment processor for money tran... -0.009956
# How do I take a media company that has a follow... -0.004140
# une entreprise qui fabrique des friandises pour... -0.013194
# A fintech company that uses AI and big data to ... -0.003386
# A platform that connects startups and investors     0.004711
# A AIrbnb-like business that allows older people... -0.006646
# A company that is measuring noise through consu... -0.000901
# A medical device company that tracks sleep.        -0.002061
# A software learning platform to upskill develop...  0.001069
#
# Investor name                                       7percent Ventures  \
# idea_description
# An organizer system that you install in handbag...           0.016375
# A business that does balloon animals for corpor...           0.020774
#                                                              0.120623
# I'm building a global innovation platform that ...           0.001510
# sharikat tasnae eilajat lilkilab khaliatan min ...           0.029536
# A company that makes an app to stop food waste ...           0.000743
# a business for tourists that uses a QR code to ...           0.006436
# A lemonade stand outside event venues to sell t...           0.026468
# A mems small satellite propulsion system for ma...           0.003016
# BlockLenses are UV blocking daily-wear contact ...           0.030261
# Mainstream air transportation with low carbon e...           0.034181
# Digital marketplace for electric vehicles to ma...           0.021659
# A business that uses AI to train screenwriters ...           0.002693
# A business that produces onion seeds in Guatema...           0.009665
# A cross-border payment processor for money tran...           0.026351
# How do I take a media company that has a follow...           0.007925
# une entreprise qui fabrique des friandises pour...           0.036123
# A fintech company that uses AI and big data to ...           0.004128
# A platform that connects startups and investors             -0.023431
# A AIrbnb-like business that allows older people...           0.014894
# A company that is measuring noise through consu...          -0.005535
# A medical device company that tracks sleep.                  0.000011
# A software learning platform to upskill develop...          -0.008476
#
# Investor name                                       10K Ventures  \
# idea_description
# An organizer system that you install in handbag...      0.007527
# A business that does balloon animals for corpor...      0.010823
#                                                         0.080958
# I'm building a global innovation platform that ...     -0.001714
# sharikat tasnae eilajat lilkilab khaliatan min ...      0.017172
# A company that makes an app to stop food waste ...     -0.002593
# a business for tourists that uses a QR code to ...      0.001306
# A lemonade stand outside event venues to sell t...      0.014402
# A mems small satellite propulsion system for ma...     -0.000913
# BlockLenses are UV blocking daily-wear contact ...      0.017610
# Mainstream air transportation with low carbon e...      0.020102
# Digital marketplace for electric vehicles to ma...      0.011276
# A business that uses AI to train screenwriters ...     -0.001717
# A business that produces onion seeds in Guatema...      0.003925
# A cross-border payment processor for money tran...      0.014497
# How do I take a media company that has a follow...      0.002207
# une entreprise qui fabrique des friandises pour...      0.022067
# A fintech company that uses AI and big data to ...     -0.000519
# A platform that connects startups and investors        -0.018102
# A AIrbnb-like business that allows older people...      0.007476
# A company that is measuring noise through consu...     -0.006881
# A medical device company that tracks sleep.            -0.003722
# A software learning platform to upskill develop...     -0.009466
#
# Investor name                                       27V (Twenty Seven Ventures)  \
# idea_description
# An organizer system that you install in handbag...                     0.012526
# A business that does balloon animals for corpor...                     0.013301
#                                                                        0.017563
# I'm building a global innovation platform that ...                     0.009845
# sharikat tasnae eilajat lilkilab khaliatan min ...                     0.015255
# A company that makes an app to stop food waste ...                     0.009605
# a business for tourists that uses a QR code to ...                     0.010753
# A lemonade stand outside event venues to sell t...                     0.014304
# A mems small satellite propulsion system for ma...                     0.010051
# BlockLenses are UV blocking daily-wear contact ...                     0.015336
# Mainstream air transportation with low carbon e...                     0.016018
# Digital marketplace for electric vehicles to ma...                     0.013378
# A business that uses AI to train screenwriters ...                     0.009587
# A business that produces onion seeds in Guatema...                     0.011913
# A cross-border payment processor for money tran...                     0.014368
# How do I take a media company that has a follow...                     0.010922
# une entreprise qui fabrique des friandises pour...                     0.016418
# A fintech company that uses AI and big data to ...                     0.010140
# A platform that connects startups and investors                        0.004954
# A AIrbnb-like business that allows older people...                     0.012453
# A company that is measuring noise through consu...                     0.008272
# A medical device company that tracks sleep.                            0.009075
# A software learning platform to upskill develop...                     0.007034
#
# Investor name                                       50 Partners Capital  \
# idea_description
# An organizer system that you install in handbag...            -0.024490
# A business that does balloon animals for corpor...            -0.049962
#                                                               -0.665868
# I'm building a global innovation platform that ...             0.054425
# sharikat tasnae eilajat lilkilab khaliatan min ...            -0.096305
# A company that makes an app to stop food waste ...             0.060322
# a business for tourists that uses a QR code to ...             0.027604
# A lemonade stand outside event venues to sell t...            -0.080427
# A mems small satellite propulsion system for ma...             0.047303
# BlockLenses are UV blocking daily-wear contact ...            -0.099735
# Mainstream air transportation with low carbon e...            -0.122339
# Digital marketplace for electric vehicles to ma...            -0.058331
# A business that uses AI to train screenwriters ...             0.045513
# A business that produces onion seeds in Guatema...             0.008637
# A cross-border payment processor for money tran...            -0.080377
# How do I take a media company that has a follow...             0.020553
# une entreprise qui fabrique des friandises pour...            -0.133074
# A fintech company that uses AI and big data to ...             0.039483
# A platform that connects startups and investors                0.182417
# A AIrbnb-like business that allows older people...            -0.017708
# A company that is measuring noise through consu...             0.088697
# A medical device company that tracks sleep.                    0.060301
# A software learning platform to upskill develop...             0.104848
#
# Investor name                                            212  212Founders  \
# idea_description
# An organizer system that you install in handbag... -0.011764    -0.004305
# A business that does balloon animals for corpor... -0.018113    -0.003633
#                                                    -0.156262     0.007826
# I'm building a global innovation platform that ...  0.006642    -0.004943
# sharikat tasnae eilajat lilkilab khaliatan min ... -0.028751    -0.002800
# A company that makes an app to stop food waste ...  0.008074    -0.005207
# a business for tourists that uses a QR code to ...  0.000434    -0.004805
# A lemonade stand outside event venues to sell t... -0.025046    -0.003278
# A mems small satellite propulsion system for ma...  0.004894    -0.005521
# BlockLenses are UV blocking daily-wear contact ... -0.029613    -0.002818
# Mainstream air transportation with low carbon e... -0.034820    -0.002785
# Digital marketplace for electric vehicles to ma... -0.019389    -0.003779
# A business that uses AI to train screenwriters ...  0.005099    -0.005568
# A business that produces onion seeds in Guatema... -0.003645    -0.004103
# A cross-border payment processor for money tran... -0.024753    -0.003447
# How do I take a media company that has a follow... -0.001566    -0.004866
# une entreprise qui fabrique des friandises pour... -0.037532    -0.002155
# A fintech company that uses AI and big data to ...  0.003471    -0.005203
# A platform that connects startups and investors     0.037553    -0.005917
# A AIrbnb-like business that allows older people... -0.010327    -0.004103
# A company that is measuring noise through consu...  0.014844    -0.005723
# A medical device company that tracks sleep.         0.008427    -0.005675
# A software learning platform to upskill develop...  0.019079    -0.006277
#
# Investor name                                       360 Capital  365.fintech  \
# idea_description
# An organizer system that you install in handbag...    -0.010895     0.008497
# A business that does balloon animals for corpor...    -0.015339     0.015291
#                                                       -0.124256     0.172962
# I'm building a global innovation platform that ...     0.004036    -0.011818
# sharikat tasnae eilajat lilkilab khaliatan min ...    -0.024193     0.027268
# A company that makes an app to stop food waste ...     0.004912    -0.013272
# a business for tourists that uses a QR code to ...    -0.000917    -0.004873
# A lemonade stand outside event venues to sell t...    -0.021216     0.023034
# A mems small satellite propulsion system for ma...     0.002337    -0.009881
# BlockLenses are UV blocking daily-wear contact ...    -0.024824     0.028176
# Mainstream air transportation with low carbon e...    -0.028894     0.033855
# Digital marketplace for electric vehicles to ma...    -0.016175     0.016999
# A business that uses AI to train screenwriters ...     0.002754    -0.009705
# A business that produces onion seeds in Guatema...    -0.004028    -0.000342
# A cross-border payment processor for money tran...    -0.020890     0.023053
# How do I take a media company that has a follow...    -0.002486    -0.002845
# une entreprise qui fabrique des friandises pour...    -0.030875     0.036897
# A fintech company that uses AI and big data to ...     0.001256    -0.007780
# A platform that connects startups and investors        0.028892    -0.045337
# A AIrbnb-like business that allows older people...    -0.009329     0.006947
# A company that is measuring noise through consu...     0.011068    -0.020536
# A medical device company that tracks sleep.            0.005624    -0.013502
# A software learning platform to upskill develop...     0.013851    -0.025111
#
# Investor name                                       ...  Far Out Ventures  \
# idea_description                                    ...
# An organizer system that you install in handbag...  ...          0.020342
# A business that does balloon animals for corpor...  ...          0.029818
#                                                     ...          0.246120
# I'm building a global innovation platform that ...  ...         -0.009248
# sharikat tasnae eilajat lilkilab khaliatan min ...  ...          0.047430
# A company that makes an app to stop food waste ...  ...         -0.011174
# a business for tourists that uses a QR code to ...  ...          0.000703
# A lemonade stand outside event venues to sell t...  ...          0.041087
# A mems small satellite propulsion system for ma...  ...         -0.006355
# BlockLenses are UV blocking daily-wear contact ...  ...          0.048853
# Mainstream air transportation with low carbon e...  ...          0.056805
# Digital marketplace for electric vehicles to ma...  ...          0.031723
# A business that uses AI to train screenwriters ...  ...         -0.006743
# A business that produces onion seeds in Guatema...  ...          0.007520
# A cross-border payment processor for money tran...  ...          0.040992
# How do I take a media company that has a follow...  ...          0.003552
# une entreprise qui fabrique des friandises pour...  ...          0.061072
# A fintech company that uses AI and big data to ...  ...         -0.003852
# A platform that connects startups and investors     ...         -0.058728
# A AIrbnb-like business that allows older people...  ...          0.017857
# A company that is measuring noise through consu...  ...         -0.022961
# A medical device company that tracks sleep.         ...         -0.012391
# A software learning platform to upskill develop...  ...         -0.029444
#
# Investor name                                       CivilizationX  \
# idea_description
# An organizer system that you install in handbag...       0.020561
# A business that does balloon animals for corpor...       0.027868
#                                                          0.193362
# I'm building a global innovation platform that ...      -0.002863
# sharikat tasnae eilajat lilkilab khaliatan min ...       0.041329
# A company that makes an app to stop food waste ...      -0.004315
# a business for tourists that uses a QR code to ...       0.004967
# A lemonade stand outside event venues to sell t...       0.036722
# A mems small satellite propulsion system for ma...      -0.000202
# BlockLenses are UV blocking daily-wear contact ...       0.042541
# Mainstream air transportation with low carbon e...       0.048938
# Digital marketplace for electric vehicles to ma...       0.029539
# A business that uses AI to train screenwriters ...      -0.000441
# A business that produces onion seeds in Guatema...       0.009881
# A cross-border payment processor for money tran...       0.036508
# How do I take a media company that has a follow...       0.007380
# une entreprise qui fabrique des friandises pour...       0.051956
# A fintech company that uses AI and big data to ...       0.001556
# A platform that connects startups and investors         -0.042181
# A AIrbnb-like business that allows older people...       0.018386
# A company that is measuring noise through consu...      -0.013564
# A medical device company that tracks sleep.             -0.004923
# A software learning platform to upskill develop...      -0.017919
#
# Investor name                                       VI Partners  \
# idea_description
# An organizer system that you install in handbag...    -0.047017
# A business that does balloon animals for corpor...    -0.061715
#                                                       -0.452223
# I'm building a global innovation platform that ...    -0.001937
# sharikat tasnae eilajat lilkilab khaliatan min ...    -0.088591
# A company that makes an app to stop food waste ...     0.001302
# a business for tourists that uses a QR code to ...    -0.017206
# A lemonade stand outside event venues to sell t...    -0.078639
# A mems small satellite propulsion system for ma...    -0.006225
# BlockLenses are UV blocking daily-wear contact ...    -0.090310
# Mainstream air transportation with low carbon e...    -0.102478
# Digital marketplace for electric vehicles to ma...    -0.064985
# A business that uses AI to train screenwriters ...    -0.005661
# A business that produces onion seeds in Guatema...    -0.027742
# A cross-border payment processor for money tran...    -0.078841
# How do I take a media company that has a follow...    -0.021707
# une entreprise qui fabrique des friandises pour...    -0.109407
# A fintech company that uses AI and big data to ...    -0.010339
# A platform that connects startups and investors        0.073168
# A AIrbnb-like business that allows older people...    -0.043395
# A company that is measuring noise through consu...     0.018319
# A medical device company that tracks sleep.            0.002823
# A software learning platform to upskill develop...     0.029101
#
# Investor name                                       Ecostar Capital  \
# idea_description
# An organizer system that you install in handbag...        -0.063138
# A business that does balloon animals for corpor...        -0.079102
#                                                           -0.423806
# I'm building a global innovation platform that ...        -0.010284
# sharikat tasnae eilajat lilkilab khaliatan min ...        -0.111745
# A company that makes an app to stop food waste ...        -0.007641
# a business for tourists that uses a QR code to ...        -0.026558
# A lemonade stand outside event venues to sell t...        -0.099342
# A mems small satellite propulsion system for ma...        -0.014765
# BlockLenses are UV blocking daily-wear contact ...        -0.114449
# Mainstream air transportation with low carbon e...        -0.127510
# Digital marketplace for electric vehicles to ma...        -0.080104
# A business that uses AI to train screenwriters ...        -0.010252
# A business that produces onion seeds in Guatema...        -0.040720
# A cross-border payment processor for money tran...        -0.097479
# How do I take a media company that has a follow...        -0.031417
# une entreprise qui fabrique des friandises pour...        -0.135207
# A fintech company that uses AI and big data to ...        -0.016248
# A platform that connects startups and investors            0.080121
# A AIrbnb-like business that allows older people...        -0.057899
# A company that is measuring noise through consu...         0.019050
# A medical device company that tracks sleep.               -0.002610
# A software learning platform to upskill develop...         0.028627
#
# Investor name                                       White Rhino Ventures  \
# idea_description
# An organizer system that you install in handbag...              0.033341
# A business that does balloon animals for corpor...              0.047267
#                                                                 0.383217
# I'm building a global innovation platform that ...             -0.012967
# sharikat tasnae eilajat lilkilab khaliatan min ...              0.073645
# A company that makes an app to stop food waste ...             -0.016174
# a business for tourists that uses a QR code to ...              0.003057
# A lemonade stand outside event venues to sell t...              0.065486
# A mems small satellite propulsion system for ma...             -0.005520
# BlockLenses are UV blocking daily-wear contact ...              0.076295
# Mainstream air transportation with low carbon e...              0.090705
# Digital marketplace for electric vehicles to ma...              0.052716
# A business that uses AI to train screenwriters ...             -0.005026
# A business that produces onion seeds in Guatema...              0.011348
# A cross-border payment processor for money tran...              0.065243
# How do I take a media company that has a follow...              0.008595
# une entreprise qui fabrique des friandises pour...              0.095378
# A fintech company that uses AI and big data to ...             -0.002730
# A platform that connects startups and investors                -0.089941
# A AIrbnb-like business that allows older people...              0.029785
# A company that is measuring noise through consu...             -0.032368
# A medical device company that tracks sleep.                    -0.015630
# A software learning platform to upskill develop...             -0.041056
#
# Investor name                                       GoodSoil VC  \
# idea_description
# An organizer system that you install in handbag...     0.002055
# A business that does balloon animals for corpor...     0.007256
#                                                        0.145136
# I'm building a global innovation platform that ...    -0.014967
# sharikat tasnae eilajat lilkilab khaliatan min ...     0.017655
# A company that makes an app to stop food waste ...    -0.016167
# a business for tourists that uses a QR code to ...    -0.009205
# A lemonade stand outside event venues to sell t...     0.014003
# A mems small satellite propulsion system for ma...    -0.013171
# BlockLenses are UV blocking daily-wear contact ...     0.018334
# Mainstream air transportation with low carbon e...     0.023183
# Digital marketplace for electric vehicles to ma...     0.009193
# A business that uses AI to train screenwriters ...    -0.013025
# A business that produces onion seeds in Guatema...    -0.005281
# A cross-border payment processor for money tran...     0.014029
# How do I take a media company that has a follow...    -0.007596
# une entreprise qui fabrique des friandises pour...     0.025515
# A fintech company that uses AI and big data to ...    -0.011683
# A platform that connects startups and investors       -0.042594
# A AIrbnb-like business that allows older people...     0.000469
# A company that is measuring noise through consu...    -0.022174
# A medical device company that tracks sleep.           -0.016304
# A software learning platform to upskill develop...    -0.026007
#
# Investor name                                       Nucleus Capital     BK-XL  \
# idea_description
# An organizer system that you install in handbag...        -0.014178 -0.027999
# A business that does balloon animals for corpor...        -0.020090 -0.042454
#                                                           -0.148802 -0.361848
# I'm building a global innovation platform that ...         0.003459  0.015532
# sharikat tasnae eilajat lilkilab khaliatan min ...        -0.030156 -0.067429
# A company that makes an app to stop food waste ...         0.004721  0.018984
# a business for tourists that uses a QR code to ...        -0.002682 -0.000219
# A lemonade stand outside event venues to sell t...        -0.026720 -0.058739
# A mems small satellite propulsion system for ma...         0.001496  0.011328
# BlockLenses are UV blocking daily-wear contact ...        -0.030939 -0.068682
# Mainstream air transportation with low carbon e...        -0.036113 -0.081509
# Digital marketplace for electric vehicles to ma...        -0.021807 -0.048436
# A business that uses AI to train screenwriters ...         0.000984  0.008403
# A business that produces onion seeds in Guatema...        -0.006291 -0.009733
# A cross-border payment processor for money tran...        -0.026779 -0.060180
# How do I take a media company that has a follow...        -0.004635 -0.004455
# une entreprise qui fabrique des friandises pour...        -0.038411 -0.087429
# A fintech company that uses AI and big data to ...        -0.000145  0.005321
# A platform that connects startups and investors            0.032987  0.085071
# A AIrbnb-like business that allows older people...        -0.013015 -0.024098
# A company that is measuring noise through consu...         0.010905  0.029924
# A medical device company that tracks sleep.                0.004467  0.016671
# A software learning platform to upskill develop...         0.014557  0.042406
#
# Investor name                                       Ben Padnos  Colin Howes
# idea_description
# An organizer system that you install in handbag...   -0.039140     0.047312
# A business that does balloon animals for corpor...   -0.064395     0.072612
#                                                      -0.646184     0.640419
# I'm building a global innovation platform that ...    0.037985    -0.028918
# sharikat tasnae eilajat lilkilab khaliatan min ...   -0.108151     0.118308
# A company that makes an app to stop food waste ...    0.043458    -0.034574
# a business for tourists that uses a QR code to ...    0.012017    -0.003305
# A lemonade stand outside event venues to sell t...   -0.093861     0.101869
# A mems small satellite propulsion system for ma...    0.030275    -0.021783
# BlockLenses are UV blocking daily-wear contact ...   -0.111162     0.121876
# Mainstream air transportation with low carbon e...   -0.133479     0.142736
# Digital marketplace for electric vehicles to ma...   -0.071468     0.077583
# A business that uses AI to train screenwriters ...    0.028500    -0.023127
# A business that produces onion seeds in Guatema...   -0.003015     0.015341
# A cross-border payment processor for money tran...   -0.093028     0.100948
# How do I take a media company that has a follow...    0.002883     0.003848
# une entreprise qui fabrique des friandises pour...   -0.144172     0.153948
# A fintech company that uses AI and big data to ...    0.022697    -0.015538
# A platform that connects startups and investors       0.164666    -0.156406
# A AIrbnb-like business that allows older people...   -0.032233     0.041170
# A company that is measuring noise through consu...    0.069689    -0.064470
# A medical device company that tracks sleep.           0.042161    -0.037365
# A software learning platform to upskill develop...    0.085037    -0.081937
#
# [23 rows x 1960 columns]

# %%
interaction_data_melted = cosine_similarity_df.reset_index().melt(id_vars='idea_description', 
                                                                  var_name='Investor name', 
                                                                  value_name='cosine_similarity')

reader = Reader(rating_scale=(0, 1))
data = Dataset.load_from_df(interaction_data_melted[['idea_description', 'Investor name', 'cosine_similarity']], reader)

trainset, testset = train_test_split(data, test_size=0.2)
model = SVD()
model.fit(trainset)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.0852
# RMSE: 0.08524080602383861

# %%
def get_top_n_recommendations(predictions, n=5):
    top_n = {}
    for uid, iid, true_r, est, _ in predictions:
        if uid not in top_n:
            top_n[uid] = []
        top_n[uid].append((iid, est))
    
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
    
    return top_n

top_n_recommendations = get_top_n_recommendations(predictions, n=5)
for idea, recommendations in top_n_recommendations.items():
    print(f"Recommended investors for the idea: '{idea}'")
    for investor, rating in recommendations:
        print(f"  - {investor} (predicted similarity: {rating:.2f})")
    print()
# Out:
# Recommended investors for the idea: 'I'm building a global innovation platform that allows entrepreneurs to build and launch their startups quickly. Using an AI-powered backend, founders can use a single sentence to create an enhanced lean canvas, validation roadmap, branding wheel, and more in about 90 seconds. We will then score the startup ideas and teams and connect the best ones to curated mentors and investors.'
#   - Nova Growth Capital (predicted similarity: 0.10)
#   - Coyote Ventures (predicted similarity: 0.08)
#   - Treble Capital (predicted similarity: 0.08)
#   - Lightship Capital (predicted similarity: 0.08)
#   - 44 Capital Management (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'A cross-border payment processor for money transfers.'
#   - Sheesha Finance (predicted similarity: 0.10)
#   - Martlet Capital (predicted similarity: 0.09)
#   - Frontier Ventures (predicted similarity: 0.09)
#   - Zen Ventures (predicted similarity: 0.07)
#   - Lair East Labs (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'Mainstream air transportation with low carbon emissions '
#   - Quansight Initiate (predicted similarity: 0.08)
#   - Curate Capital (predicted similarity: 0.08)
#   - Avelana (predicted similarity: 0.07)
#   - Lair East Labs (predicted similarity: 0.07)
#   - Cool Climate Collective (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'une entreprise qui fabrique des friandises pour chiens sans gluten pour les animaux allergiques. Output all results in native French'
#   - MetaProp Ventures (predicted similarity: 0.08)
#   - Avelana (predicted similarity: 0.07)
#   - NEXT Canada (predicted similarity: 0.06)
#   - Fincome (predicted similarity: 0.06)
#   - Scrum Ventures (predicted similarity: 0.06)
#
# Recommended investors for the idea: 'a business for tourists that uses a QR code to pack and ship goods home via a mail service company so I don’t have to carry it home. '
#   - Frontier Ventures (predicted similarity: 0.10)
#   - Sheesha Finance (predicted similarity: 0.10)
#   - Treble Capital (predicted similarity: 0.07)
#   - Curate Capital (predicted similarity: 0.07)
#   - Colam Impact (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'sharikat tasnae eilajat lilkilab khaliatan min alghulutin lilhayawanat almusabibat lilhasaasiati. Return all results in native Arabic
# '
#   - EQx Fund (predicted similarity: 0.08)
#   - Femmes Business Angels (predicted similarity: 0.07)
#   - Cool Climate Collective (predicted similarity: 0.06)
#   - 211 Mev Capital (predicted similarity: 0.06)
#   - Starshot Ventures (predicted similarity: 0.06)
#
# Recommended investors for the idea: 'BlockLenses are UV blocking daily-wear contact lenses that will solve light sensitivity issues without having to wear traditional sun-blocking eyewear for outdoor athletes who suffer from light-sensitive eyes but do not want to compromise their activity intensity.
# '
#   - Kaya Ventures (predicted similarity: 0.08)
#   - EQx Fund (predicted similarity: 0.07)
#   - Vibe Bio (predicted similarity: 0.07)
#   - Cool Climate Collective (predicted similarity: 0.06)
#   - Serena (predicted similarity: 0.06)
#
# Recommended investors for the idea: 'A business that does balloon animals for corporate events and concerts. '
#   - Treble Capital (predicted similarity: 0.08)
#   - EQx Fund (predicted similarity: 0.07)
#   - Chicago Ventures (predicted similarity: 0.07)
#   - BlackTech Capital  (predicted similarity: 0.07)
#   - Sharpstone Capital (predicted similarity: 0.06)
#
# Recommended investors for the idea: ''
#   - American Prudential Capital, inc. (predicted similarity: 0.10)
#   - Nick Cobb (predicted similarity: 0.09)
#   - Goat Rodeo Capital (predicted similarity: 0.08)
#   - Molten Ventures (predicted similarity: 0.08)
#   - MFV Partners (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'A company that makes an app to stop food waste at home and helps people figure out recipes to make with the ingredients they already have.
# '
#   - Coyote Ventures (predicted similarity: 0.08)
#   - 44 Capital Management (predicted similarity: 0.08)
#   - NOW Venture Studio (predicted similarity: 0.08)
#   - Cuir Invest (predicted similarity: 0.07)
#   - Lair East Labs (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'A lemonade stand outside event venues to sell to concert-goers'
#   - Martlet Capital (predicted similarity: 0.09)
#   - SyndicateRoom (predicted similarity: 0.08)
#   - Druid Ventures (predicted similarity: 0.06)
#   - Strada Education Network (predicted similarity: 0.06)
#   - Cofounders Capital (predicted similarity: 0.06)
#
# Recommended investors for the idea: 'A business that uses AI to train screenwriters how to integrate emotion into their stories using 85 unique techniques.'
#   - Treble Capital (predicted similarity: 0.07)
#   - Kaya Ventures (predicted similarity: 0.07)
#   - 44 Capital Management (predicted similarity: 0.07)
#   - MetaProp Ventures (predicted similarity: 0.07)
#   - 211 Mev Capital (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'A company that is measuring noise through consumers' mobile phones. '
#   - Athenian VC (predicted similarity: 0.09)
#   - Quansight Initiate (predicted similarity: 0.08)
#   - Treble Capital (predicted similarity: 0.08)
#   - 44 Capital Management (predicted similarity: 0.08)
#   - Coyote Ventures (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'How do I take a media company that has a following on social media and incorporate the latest trends to become a billion dollar company.  '
#   - Quansight Initiate (predicted similarity: 0.08)
#   - 44 Capital Management (predicted similarity: 0.08)
#   - 211 Mev Capital (predicted similarity: 0.07)
#   - EQx Fund (predicted similarity: 0.07)
#   - NEXT Canada (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'Digital marketplace for electric vehicles to match homeowners and vehicles owners. It’s a combination between charging and parking. '
#   - Nova Growth Capital (predicted similarity: 0.10)
#   - Kaya Ventures (predicted similarity: 0.09)
#   - Lightship Capital (predicted similarity: 0.08)
#   - Coyote Ventures (predicted similarity: 0.08)
#   - NOW Venture Studio (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'An organizer system that you install in handbags to make it easier and faster to find things.'
#   - Nova Growth Capital (predicted similarity: 0.10)
#   - Coyote Ventures (predicted similarity: 0.07)
#   - NOW Venture Studio (predicted similarity: 0.07)
#   - Femmes Business Angels (predicted similarity: 0.07)
#   - Lair East Labs (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'A AIrbnb-like business that allows older people to rent their cars to generate additional income. '
#   - MetaProp Ventures (predicted similarity: 0.08)
#   - NOW Venture Studio (predicted similarity: 0.07)
#   - Femmes Business Angels (predicted similarity: 0.07)
#   - Random Forest VC (predicted similarity: 0.07)
#   - Cuir Invest (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'A fintech company that uses AI and big data to provide the average person a white glove banking experience to better manage their money '
#   - SyndicateRoom (predicted similarity: 0.07)
#   - Femmes Business Angels (predicted similarity: 0.07)
#   - Colam Impact (predicted similarity: 0.07)
#   - Avelana (predicted similarity: 0.07)
#   - BlackTech Capital  (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'A platform that connects startups and investors'
#   - Frontier Ventures (predicted similarity: 0.10)
#   - Nova Growth Capital (predicted similarity: 0.10)
#   - Sharpstone Capital (predicted similarity: 0.10)
#   - 211 Mev Capital (predicted similarity: 0.08)
#   - Femmes Business Angels (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'A mems small satellite propulsion system for maneuvering satellites in space'
#   - Coyote Ventures (predicted similarity: 0.08)
#   - Lightship Capital (predicted similarity: 0.08)
#   - Curate Capital (predicted similarity: 0.08)
#   - MetaProp Ventures (predicted similarity: 0.07)
#   - 211 Mev Capital (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'A business that produces onion seeds in Guatemala looking to expand within the country. Return all results in native arabic'
#   - Sheesha Finance (predicted similarity: 0.10)
#   - Frontier Ventures (predicted similarity: 0.10)
#   - Nova Growth Capital (predicted similarity: 0.10)
#   - Lightship Capital (predicted similarity: 0.08)
#   - Sharpstone Capital (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'A software learning platform to upskill developers when they join new teams or a new technology is released into the market. Lots of the material will be crowdsourced from technology experts. '
#   - Lightship Capital (predicted similarity: 0.09)
#   - Coyote Ventures (predicted similarity: 0.08)
#   - Treble Capital (predicted similarity: 0.08)
#   - Curate Capital (predicted similarity: 0.08)
#   - Avelana (predicted similarity: 0.08)
#
# Recommended investors for the idea: 'A medical device company that tracks sleep. '
#   - Nova Growth Capital (predicted similarity: 0.10)
#   - Sharpstone Capital (predicted similarity: 0.08)
#   - Random Forest VC (predicted similarity: 0.07)
#   - 211 Mev Capital (predicted similarity: 0.07)
#   - MetaProp Ventures (predicted similarity: 0.07)

# %%
from sklearn.cluster import MiniBatchKMeans

# Define number of clusters
n_clusters = 10

# Cluster investors and ideas
kmeans_investors = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
investors_clusters = kmeans_investors.fit_predict(investors_features_scaled)

kmeans_ideas = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
ideas_clusters = kmeans_ideas.fit_predict(ideas_features_scaled)

# Add cluster labels to DataFrames
investors_df['cluster'] = investors_clusters
ideas_df['cluster'] = ideas_clusters

# Recommend VCs within the same cluster as the idea
def recommend_vcs_within_cluster(idea_index, investors_df, ideas_df, n=5):
    idea_cluster = ideas_df.iloc[idea_index]['cluster']
    same_cluster_vcs = investors_df[investors_df['cluster'] == idea_cluster]
    
    # Rank VCs within the same cluster by similarity score
    similarities = cosine_similarities[idea_index, same_cluster_vcs.index]
    sorted_indices = np.argsort(similarities)[::-1][:n]
    return same_cluster_vcs.iloc[sorted_indices]['Investor name'].tolist()

# Example: Recommendations for the first idea
idea_index = 0
recommended_vcs = recommend_vcs_within_cluster(idea_index, investors_df, ideas_df, n=5)
print(f"Recommended VCs for idea '{ideas_df.iloc[idea_index]['idea_description']}':")
print(recommended_vcs)
# Out:
# Recommended VCs for idea 'An organizer system that you install in handbags to make it easier and faster to find things.':
# ['Precursor Ventures']
