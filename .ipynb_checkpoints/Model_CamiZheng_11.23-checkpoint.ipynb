# %%
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score
from surprise import SVD, Dataset, Reader, accuracy
from surprise.model_selection import train_test_split
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
import nltk


nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\one_w\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\one_w\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Load datasets
investors_df = pd.read_csv('cleaned_openvc.csv')
ideas_df = pd.read_csv('cleaned_ideas.csv')

# Fill NaN values with an empty string
ideas_df['idea_description'] = ideas_df['idea_description'].fillna("")
investors_df['Investment thesis'] = investors_df['Investment thesis'].fillna("")

# Preprocess the text
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = re.sub(r'\W+', ' ', text)  # Remove punctuation
    words = text.lower().split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # Lemmatize and remove stopwords
    return words

investment_sentences = investors_df['Investment thesis'].apply(preprocess_text).tolist()
idea_sentences = ideas_df['idea_description'].apply(preprocess_text).tolist()

# %%
all_sentences = investment_sentences + idea_sentences
model = Word2Vec(sentences=all_sentences, vector_size=200, window=10, min_count=5, workers=4)

# %%
def compute_text_embedding(text, model):
    words = preprocess_text(text)
    valid_words = [model.wv[word] for word in words if word in model.wv]
    if valid_words:
        return np.mean(valid_words, axis=0)
    else:
        return np.zeros(model.vector_size)

investors_df['embedding'] = investors_df['Investment thesis'].apply(lambda x: compute_text_embedding(x, model))
ideas_df['embedding'] = ideas_df['idea_description'].apply(lambda x: compute_text_embedding(x, model))

# %%
def encode_and_combine(df, columns):
    encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    encoded = encoder.fit_transform(df[columns])
    return pd.DataFrame(encoded, index=df.index)

investors_categoricals = encode_and_combine(investors_df, ['Countries of investment', 'Stage of investment', 'Investor type'])
ideas_categoricals = encode_and_combine(ideas_df, ['user_last_ip_country_name'])

# %%
investors_features = pd.concat([investors_categoricals, investors_df['embedding'].apply(pd.Series)], axis=1)
ideas_features = pd.concat([ideas_categoricals, ideas_df['embedding'].apply(pd.Series)], axis=1)

# Align feature dimensions and scale
investors_features_aligned, ideas_features_aligned = investors_features.align(ideas_features, fill_value=0, axis=1)
scaler = StandardScaler()
investors_features_scaled = scaler.fit_transform(investors_features_aligned)
ideas_features_scaled = scaler.transform(ideas_features_aligned)

# %%
cosine_similarities = cosine_similarity(ideas_features_scaled, investors_features_scaled)
cosine_similarity_df = pd.DataFrame(cosine_similarities, columns=investors_df['Investor name'], index=ideas_df['idea_description'])
print(cosine_similarity_df)
# Out:
# Investor name                                       3TS Capital Partners  \
# idea_description
# An organizer system that you install in handbag...              0.019727
# A business that does balloon animals for corpor...              0.028093
#                                                                 0.085702
# I'm building a global innovation platform that ...              0.000639
# sharikat tasnae eilajat lilkilab khaliatan min ...              0.039780
# A company that makes an app to stop food waste ...             -0.003100
# a business for tourists that uses a QR code to ...              0.006327
# A lemonade stand outside event venues to sell t...              0.036516
# A mems small satellite propulsion system for ma...              0.002916
# BlockLenses are UV blocking daily-wear contact ...              0.036944
# Mainstream air transportation with low carbon e...              0.044060
# Digital marketplace for electric vehicles to ma...              0.026029
# A business that uses AI to train screenwriters ...              0.001032
# A business that produces onion seeds in Guatema...              0.009497
# A cross-border payment processor for money tran...              0.035765
# How do I take a media company that has a follow...              0.008020
# une entreprise qui fabrique des friandises pour...              0.049052
# A fintech company that uses AI and big data to ...              0.001920
# A platform that connects startups and investors                -0.028919
# A AIrbnb-like business that allows older people...              0.016225
# A company that is measuring noise through consu...             -0.008475
# A medical device company that tracks sleep.                    -0.001143
# A software learning platform to upskill develop...             -0.012113
#
# Investor name                                            3VC  \
# idea_description
# An organizer system that you install in handbag... -0.030389
# A business that does balloon animals for corpor... -0.033420
#                                                    -0.056510
# I'm building a global innovation platform that ... -0.024554
# sharikat tasnae eilajat lilkilab khaliatan min ... -0.036813
# A company that makes an app to stop food waste ... -0.022516
# a business for tourists that uses a QR code to ... -0.026142
# A lemonade stand outside event venues to sell t... -0.036594
# A mems small satellite propulsion system for ma... -0.024935
# BlockLenses are UV blocking daily-wear contact ... -0.035949
# Mainstream air transportation with low carbon e... -0.037405
# Digital marketplace for electric vehicles to ma... -0.032587
# A business that uses AI to train screenwriters ... -0.024375
# A business that produces onion seeds in Guatema... -0.027979
# A cross-border payment processor for money tran... -0.035769
# How do I take a media company that has a follow... -0.026385
# une entreprise qui fabrique des friandises pour... -0.039736
# A fintech company that uses AI and big data to ... -0.025273
# A platform that connects startups and investors    -0.013081
# A AIrbnb-like business that allows older people... -0.030042
# A company that is measuring noise through consu... -0.021785
# A medical device company that tracks sleep.        -0.023499
# A software learning platform to upskill develop... -0.018606
#
# Investor name                                       7percent Ventures  \
# idea_description
# An organizer system that you install in handbag...           0.023134
# A business that does balloon animals for corpor...           0.032187
#                                                              0.087646
# I'm building a global innovation platform that ...           0.003690
# sharikat tasnae eilajat lilkilab khaliatan min ...           0.044257
# A company that makes an app to stop food waste ...          -0.000485
# a business for tourists that uses a QR code to ...           0.009121
# A lemonade stand outside event venues to sell t...           0.040874
# A mems small satellite propulsion system for ma...           0.005388
# BlockLenses are UV blocking daily-wear contact ...           0.041258
# Mainstream air transportation with low carbon e...           0.048729
# Digital marketplace for electric vehicles to ma...           0.029071
# A business that uses AI to train screenwriters ...           0.003473
# A business that produces onion seeds in Guatema...           0.013240
# A cross-border payment processor for money tran...           0.039521
# How do I take a media company that has a follow...           0.010953
# une entreprise qui fabrique des friandises pour...           0.053905
# A fintech company that uses AI and big data to ...           0.004504
# A platform that connects startups and investors             -0.027381
# A AIrbnb-like business that allows older people...           0.019694
# A company that is measuring noise through consu...          -0.006844
# A medical device company that tracks sleep.                  0.000845
# A software learning platform to upskill develop...          -0.010329
#
# Investor name                                       10K Ventures  \
# idea_description
# An organizer system that you install in handbag...      0.014396
# A business that does balloon animals for corpor...      0.021742
#                                                         0.062161
# I'm building a global innovation platform that ...      0.000540
# sharikat tasnae eilajat lilkilab khaliatan min ...      0.031244
# A company that makes an app to stop food waste ...     -0.003224
# a business for tourists that uses a QR code to ...      0.004128
# A lemonade stand outside event venues to sell t...      0.028251
# A mems small satellite propulsion system for ma...      0.001415
# BlockLenses are UV blocking daily-wear contact ...      0.029087
# Mainstream air transportation with low carbon e...      0.034492
# Digital marketplace for electric vehicles to ma...      0.019214
# A business that uses AI to train screenwriters ...     -0.000312
# A business that produces onion seeds in Guatema...      0.007913
# A cross-border payment processor for money tran...      0.027393
# How do I take a media company that has a follow...      0.005442
# une entreprise qui fabrique des friandises pour...      0.038977
# A fintech company that uses AI and big data to ...      0.000644
# A platform that connects startups and investors        -0.022763
# A AIrbnb-like business that allows older people...      0.012666
# A company that is measuring noise through consu...     -0.008195
# A medical device company that tracks sleep.            -0.002143
# A software learning platform to upskill develop...     -0.010842
#
# Investor name                                       27V (Twenty Seven Ventures)  \
# idea_description
# An organizer system that you install in handbag...                     0.016272
# A business that does balloon animals for corpor...                     0.021001
#                                                                        0.035188
# I'm building a global innovation platform that ...                     0.006505
# sharikat tasnae eilajat lilkilab khaliatan min ...                     0.026693
# A company that makes an app to stop food waste ...                     0.003887
# a business for tourists that uses a QR code to ...                     0.008879
# A lemonade stand outside event venues to sell t...                     0.024639
# A mems small satellite propulsion system for ma...                     0.007252
# BlockLenses are UV blocking daily-wear contact ...                     0.025634
# Mainstream air transportation with low carbon e...                     0.029235
# Digital marketplace for electric vehicles to ma...                     0.018964
# A business that uses AI to train screenwriters ...                     0.005848
# A business that produces onion seeds in Guatema...                     0.012200
# A cross-border payment processor for money tran...                     0.024274
# How do I take a media company that has a follow...                     0.010003
# une entreprise qui fabrique des friandises pour...                     0.031640
# A fintech company that uses AI and big data to ...                     0.006369
# A platform that connects startups and investors                       -0.009995
# A AIrbnb-like business that allows older people...                     0.015072
# A company that is measuring noise through consu...                     0.000697
# A medical device company that tracks sleep.                            0.004518
# A software learning platform to upskill develop...                    -0.001338
#
# Investor name                                       50 Partners Capital  \
# idea_description
# An organizer system that you install in handbag...            -0.103882
# A business that does balloon animals for corpor...            -0.158648
#                                                               -0.555549
# I'm building a global innovation platform that ...             0.012954
# sharikat tasnae eilajat lilkilab khaliatan min ...            -0.233342
# A company that makes an app to stop food waste ...             0.040041
# a business for tourists that uses a QR code to ...            -0.020629
# A lemonade stand outside event venues to sell t...            -0.213431
# A mems small satellite propulsion system for ma...             0.001088
# BlockLenses are UV blocking daily-wear contact ...            -0.216947
# Mainstream air transportation with low carbon e...            -0.262340
# Digital marketplace for electric vehicles to ma...            -0.147771
# A business that uses AI to train screenwriters ...             0.012702
# A business that produces onion seeds in Guatema...            -0.044307
# A cross-border payment processor for money tran...            -0.208726
# How do I take a media company that has a follow...            -0.030793
# une entreprise qui fabrique des friandises pour...            -0.294960
# A fintech company that uses AI and big data to ...             0.004821
# A platform that connects startups and investors                0.196463
# A AIrbnb-like business that allows older people...            -0.085527
# A company that is measuring noise through consu...             0.070666
# A medical device company that tracks sleep.                    0.027809
# A software learning platform to upskill develop...             0.096232
#
# Investor name                                            212  212Founders  \
# idea_description
# An organizer system that you install in handbag... -0.022291     0.001055
# A business that does balloon animals for corpor... -0.033642     0.003769
#                                                    -0.112239     0.014373
# I'm building a global innovation platform that ...  0.001753    -0.001944
# sharikat tasnae eilajat lilkilab khaliatan min ... -0.049019     0.006707
# A company that makes an app to stop food waste ...  0.007225    -0.003459
# a business for tourists that uses a QR code to ... -0.005006    -0.001497
# A lemonade stand outside event venues to sell t... -0.044445     0.006095
# A mems small satellite propulsion system for ma... -0.000684    -0.002828
# BlockLenses are UV blocking daily-wear contact ... -0.045072     0.005955
# Mainstream air transportation with low carbon e... -0.054238     0.007686
# Digital marketplace for electric vehicles to ma... -0.030843     0.002699
# A business that uses AI to train screenwriters ...  0.001712    -0.002775
# A business that produces onion seeds in Guatema... -0.009897     0.000103
# A cross-border payment processor for money tran... -0.043712     0.004857
# How do I take a media company that has a follow... -0.007342    -0.001162
# une entreprise qui fabrique des friandises pour... -0.061482     0.009248
# A fintech company that uses AI and big data to ...  0.000443    -0.002342
# A platform that connects startups and investors     0.039737    -0.007795
# A AIrbnb-like business that allows older people... -0.018477     0.001021
# A company that is measuring noise through consu...  0.013328    -0.005240
# A medical device company that tracks sleep.         0.004614    -0.003580
# A software learning platform to upskill develop...  0.019017    -0.005862
#
# Investor name                                       360 Capital  365.fintech  \
# idea_description
# An organizer system that you install in handbag...    -0.022538     0.026162
# A business that does balloon animals for corpor...    -0.032404     0.039206
#                                                       -0.102105     0.134489
# I'm building a global innovation platform that ...     0.000034    -0.001939
# sharikat tasnae eilajat lilkilab khaliatan min ...    -0.046385     0.057874
# A company that makes an app to stop food waste ...     0.004274    -0.008352
# a business for tourists that uses a QR code to ...    -0.006633     0.006063
# A lemonade stand outside event venues to sell t...    -0.041794     0.052509
# A mems small satellite propulsion system for ma...    -0.002576     0.001238
# BlockLenses are UV blocking daily-wear contact ...    -0.042668     0.053505
# Mainstream air transportation with low carbon e...    -0.051032     0.064543
# Digital marketplace for electric vehicles to ma...    -0.029231     0.036749
# A business that uses AI to train screenwriters ...     0.000259    -0.002148
# A business that produces onion seeds in Guatema...    -0.010926     0.011520
# A cross-border payment processor for money tran...    -0.041282     0.052021
# How do I take a media company that has a follow...    -0.008694     0.008709
# une entreprise qui fabrique des friandises pour...    -0.057106     0.072601
# A fintech company that uses AI and big data to ...    -0.000973     0.000338
# A platform that connects startups and investors        0.034788    -0.046464
# A AIrbnb-like business that allows older people...    -0.018371     0.021765
# A company that is measuring noise through consu...     0.011523    -0.015504
# A medical device company that tracks sleep.            0.002700    -0.005387
# A software learning platform to upskill develop...     0.015335    -0.022291
#
# Investor name                                       ...  Far Out Ventures  \
# idea_description                                    ...
# An organizer system that you install in handbag...  ...          0.047356
# A business that does balloon animals for corpor...  ...          0.068674
#                                                     ...          0.208689
# I'm building a global innovation platform that ...  ...          0.001062
# sharikat tasnae eilajat lilkilab khaliatan min ...  ...          0.098452
# A company that makes an app to stop food waste ...  ...         -0.009250
# a business for tourists that uses a QR code to ...  ...          0.013975
# A lemonade stand outside event venues to sell t...  ...          0.089286
# A mems small satellite propulsion system for ma...  ...          0.005503
# BlockLenses are UV blocking daily-wear contact ...  ...          0.091379
# Mainstream air transportation with low carbon e...  ...          0.108747
# Digital marketplace for electric vehicles to ma...  ...          0.062695
# A business that uses AI to train screenwriters ...  ...          0.000309
# A business that produces onion seeds in Guatema...  ...          0.024153
# A cross-border payment processor for money tran...  ...          0.087435
# How do I take a media company that has a follow...  ...          0.018315
# une entreprise qui fabrique des friandises pour...  ...          0.121893
# A fintech company that uses AI and big data to ...  ...          0.003413
# A platform that connects startups and investors     ...         -0.072432
# A AIrbnb-like business that allows older people...  ...          0.039758
# A company that is measuring noise through consu...  ...         -0.023041
# A medical device company that tracks sleep.         ...         -0.005385
# A software learning platform to upskill develop...  ...         -0.032412
#
# Investor name                                       CivilizationX  \
# idea_description
# An organizer system that you install in handbag...       0.032446
# A business that does balloon animals for corpor...       0.046140
#                                                          0.139966
# I'm building a global innovation platform that ...       0.001912
# sharikat tasnae eilajat lilkilab khaliatan min ...       0.065541
# A company that makes an app to stop food waste ...      -0.004327
# a business for tourists that uses a QR code to ...       0.010802
# A lemonade stand outside event venues to sell t...       0.059808
# A mems small satellite propulsion system for ma...       0.005578
# BlockLenses are UV blocking daily-wear contact ...       0.060741
# Mainstream air transportation with low carbon e...       0.072269
# Digital marketplace for electric vehicles to ma...       0.042817
# A business that uses AI to train screenwriters ...       0.002022
# A business that produces onion seeds in Guatema...       0.016285
# A cross-border payment processor for money tran...       0.058803
# How do I take a media company that has a follow...       0.013503
# une entreprise qui fabrique des friandises pour...       0.080670
# A fintech company that uses AI and big data to ...       0.003963
# A platform that connects startups and investors         -0.046078
# A AIrbnb-like business that allows older people...       0.027105
# A company that is measuring noise through consu...      -0.013183
# A medical device company that tracks sleep.             -0.001663
# A software learning platform to upskill develop...      -0.019217
#
# Investor name                                       VI Partners  \
# idea_description
# An organizer system that you install in handbag...    -0.111337
# A business that does balloon animals for corpor...    -0.144667
#                                                       -0.378579
# I'm building a global innovation platform that ...    -0.038487
# sharikat tasnae eilajat lilkilab khaliatan min ...    -0.191593
# A company that makes an app to stop food waste ...    -0.021398
# a business for tourists that uses a QR code to ...    -0.058799
# A lemonade stand outside event venues to sell t...    -0.177028
# A mems small satellite propulsion system for ma...    -0.045794
# BlockLenses are UV blocking daily-wear contact ...    -0.179871
# Mainstream air transportation with low carbon e...    -0.206934
# Digital marketplace for electric vehicles to ma...    -0.136248
# A business that uses AI to train screenwriters ...    -0.037303
# A business that produces onion seeds in Guatema...    -0.074612
# A cross-border payment processor for money tran...    -0.175036
# How do I take a media company that has a follow...    -0.066119
# une entreprise qui fabrique des friandises pour...    -0.227676
# A fintech company that uses AI and big data to ...    -0.042738
# A platform that connects startups and investors        0.079777
# A AIrbnb-like business that allows older people...    -0.099875
# A company that is measuring noise through consu...    -0.001531
# A medical device company that tracks sleep.           -0.028186
# A software learning platform to upskill develop...     0.015653
#
# Investor name                                       Ecostar Capital  \
# idea_description
# An organizer system that you install in handbag...        -0.093386
# A business that does balloon animals for corpor...        -0.132460
#                                                           -0.347682
# I'm building a global innovation platform that ...        -0.014120
# sharikat tasnae eilajat lilkilab khaliatan min ...        -0.187181
# A company that makes an app to stop food waste ...         0.003235
# a business for tourists that uses a QR code to ...        -0.034050
# A lemonade stand outside event venues to sell t...        -0.167433
# A mems small satellite propulsion system for ma...        -0.018375
# BlockLenses are UV blocking daily-wear contact ...        -0.172065
# Mainstream air transportation with low carbon e...        -0.203175
# Digital marketplace for electric vehicles to ma...        -0.114639
# A business that uses AI to train screenwriters ...        -0.006924
# A business that produces onion seeds in Guatema...        -0.056071
# A cross-border payment processor for money tran...        -0.161455
# How do I take a media company that has a follow...        -0.042723
# une entreprise qui fabrique des friandises pour...        -0.226951
# A fintech company that uses AI and big data to ...        -0.014287
# A platform that connects startups and investors            0.118657
# A AIrbnb-like business that allows older people...        -0.080994
# A company that is measuring noise through consu...         0.035863
# A medical device company that tracks sleep.               -0.000126
# A software learning platform to upskill develop...         0.047448
#
# Investor name                                       White Rhino Ventures  \
# idea_description
# An organizer system that you install in handbag...              0.032768
# A business that does balloon animals for corpor...              0.050840
#                                                                 0.174608
# I'm building a global innovation platform that ...             -0.005767
# sharikat tasnae eilajat lilkilab khaliatan min ...              0.070470
# A company that makes an app to stop food waste ...             -0.012647
# a business for tourists that uses a QR code to ...              0.007588
# A lemonade stand outside event venues to sell t...              0.067734
# A mems small satellite propulsion system for ma...              0.000546
# BlockLenses are UV blocking daily-wear contact ...              0.066663
# Mainstream air transportation with low carbon e...              0.082178
# Digital marketplace for electric vehicles to ma...              0.047164
# A business that uses AI to train screenwriters ...             -0.001092
# A business that produces onion seeds in Guatema...              0.010432
# A cross-border payment processor for money tran...              0.064588
# How do I take a media company that has a follow...              0.009751
# une entreprise qui fabrique des friandises pour...              0.090308
# A fintech company that uses AI and big data to ...             -0.002942
# A platform that connects startups and investors                -0.062171
# A AIrbnb-like business that allows older people...              0.024919
# A company that is measuring noise through consu...             -0.024658
# A medical device company that tracks sleep.                    -0.008617
# A software learning platform to upskill develop...             -0.029298
#
# Investor name                                       GoodSoil VC  \
# idea_description
# An organizer system that you install in handbag...     0.012215
# A business that does balloon animals for corpor...     0.019469
#                                                        0.082635
# I'm building a global innovation platform that ...    -0.004977
# sharikat tasnae eilajat lilkilab khaliatan min ...     0.030185
# A company that makes an app to stop food waste ...    -0.008660
# a business for tourists that uses a QR code to ...     0.000023
# A lemonade stand outside event venues to sell t...     0.027347
# A mems small satellite propulsion system for ma...    -0.002638
# BlockLenses are UV blocking daily-wear contact ...     0.027770
# Mainstream air transportation with low carbon e...     0.034492
# Digital marketplace for electric vehicles to ma...     0.018595
# A business that uses AI to train screenwriters ...    -0.004513
# A business that produces onion seeds in Guatema...     0.002989
# A cross-border payment processor for money tran...     0.027268
# How do I take a media company that has a follow...     0.001600
# une entreprise qui fabrique des friandises pour...     0.038955
# A fintech company that uses AI and big data to ...    -0.003387
# A platform that connects startups and investors       -0.030703
# A AIrbnb-like business that allows older people...     0.009072
# A company that is measuring noise through consu...    -0.012257
# A medical device company that tracks sleep.           -0.006955
# A software learning platform to upskill develop...    -0.016450
#
# Investor name                                       Nucleus Capital     BK-XL  \
# idea_description
# An organizer system that you install in handbag...        -0.018318 -0.063346
# A business that does balloon animals for corpor...        -0.026264 -0.092698
#                                                           -0.084490 -0.314819
# I'm building a global innovation platform that ...        -0.001242  0.004224
# sharikat tasnae eilajat lilkilab khaliatan min ...        -0.036913 -0.134252
# A company that makes an app to stop food waste ...         0.002588  0.019691
# a business for tourists that uses a QR code to ...        -0.006382 -0.016110
# A lemonade stand outside event venues to sell t...        -0.034267 -0.123658
# A mems small satellite propulsion system for ma...        -0.003290 -0.004969
# BlockLenses are UV blocking daily-wear contact ...        -0.034375 -0.125338
# Mainstream air transportation with low carbon e...        -0.040892 -0.151048
# Digital marketplace for electric vehicles to ma...        -0.025012 -0.090015
# A business that uses AI to train screenwriters ...        -0.002040  0.001416
# A business that produces onion seeds in Guatema...        -0.009071 -0.028131
# A cross-border payment processor for money tran...        -0.033603 -0.124117
# How do I take a media company that has a follow...        -0.007935 -0.022248
# une entreprise qui fabrique des friandises pour...        -0.045725 -0.169175
# A fintech company that uses AI and big data to ...        -0.002662 -0.002497
# A platform that connects startups and investors            0.025511  0.107224
# A AIrbnb-like business that allows older people...        -0.015587 -0.052424
# A company that is measuring noise through consu...         0.006346  0.029623
# A medical device company that tracks sleep.                0.000325  0.009530
# A software learning platform to upskill develop...         0.010651  0.050301
#
# Investor name                                       Ben Padnos  Colin Howes
# idea_description
# An organizer system that you install in handbag...   -0.106056     0.104750
# A business that does balloon animals for corpor...   -0.157803     0.155004
#                                                      -0.539210     0.480534
# I'm building a global innovation platform that ...    0.008427    -0.000919
# sharikat tasnae eilajat lilkilab khaliatan min ...   -0.233345     0.222844
# A company that makes an app to stop food waste ...    0.032116    -0.024904
# a business for tourists that uses a QR code to ...   -0.025918     0.028696
# A lemonade stand outside event venues to sell t...   -0.211935     0.202402
# A mems small satellite propulsion system for ma...   -0.005757     0.009259
# BlockLenses are UV blocking daily-wear contact ...   -0.213615     0.206247
# Mainstream air transportation with low carbon e...   -0.258815     0.247496
# Digital marketplace for electric vehicles to ma...   -0.149719     0.140306
# A business that uses AI to train screenwriters ...    0.006687    -0.003909
# A business that produces onion seeds in Guatema...   -0.043500     0.052409
# A cross-border payment processor for money tran...   -0.210272     0.198747
# How do I take a media company that has a follow...   -0.036416     0.038799
# une entreprise qui fabrique des friandises pour...   -0.291622     0.277483
# A fintech company that uses AI and big data to ...   -0.001041     0.004363
# A platform that connects startups and investors       0.186296    -0.168727
# A AIrbnb-like business that allows older people...   -0.086322     0.087981
# A company that is measuring noise through consu...    0.059833    -0.056299
# A medical device company that tracks sleep.           0.018495    -0.015913
# A software learning platform to upskill develop...    0.087407    -0.078578
#
# [23 rows x 1960 columns]

# %%
interaction_data_melted = cosine_similarity_df.reset_index().melt(id_vars='idea_description', 
                                                                  var_name='Investor name', 
                                                                  value_name='cosine_similarity')

reader = Reader(rating_scale=(0, 1))
data = Dataset.load_from_df(interaction_data_melted[['idea_description', 'Investor name', 'cosine_similarity']], reader)

trainset, testset = train_test_split(data, test_size=0.2)
model = SVD()
model.fit(trainset)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.0917
# RMSE: 0.09167075526119813

# %%
def get_top_n_recommendations(predictions, n=5):
    top_n = {}
    for uid, iid, true_r, est, _ in predictions:
        if uid not in top_n:
            top_n[uid] = []
        top_n[uid].append((iid, est))
    
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
    
    return top_n

top_n_recommendations = get_top_n_recommendations(predictions, n=5)
for idea, recommendations in top_n_recommendations.items():
    print(f"Recommended investors for the idea: '{idea}'")
    for investor, rating in recommendations:
        print(f"  - {investor} (predicted similarity: {rating:.2f})")
    print()
# Out:
# Recommended investors for the idea: 'A fintech company that uses AI and big data to provide the average person a white glove banking experience to better manage their money '
#   - Cool Climate Collective (predicted similarity: 0.12)
#   - Lexi Ventures (predicted similarity: 0.11)
#   - Engineering Capital (predicted similarity: 0.11)
#   - Northwestern Mutual Future Ventures (predicted similarity: 0.10)
#   - Fincome (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'I'm building a global innovation platform that allows entrepreneurs to build and launch their startups quickly. Using an AI-powered backend, founders can use a single sentence to create an enhanced lean canvas, validation roadmap, branding wheel, and more in about 90 seconds. We will then score the startup ideas and teams and connect the best ones to curated mentors and investors.'
#   - The Helm (predicted similarity: 0.12)
#   - Lexi Ventures (predicted similarity: 0.11)
#   - StartCapital Partners (predicted similarity: 0.11)
#   - Fincome (predicted similarity: 0.10)
#   - Anthropocene Ventures (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'A medical device company that tracks sleep. '
#   - Halogen Ventures (predicted similarity: 0.12)
#   - Lexi Ventures (predicted similarity: 0.11)
#   - American Prudential Capital, inc. (predicted similarity: 0.11)
#   - Anthropocene Ventures (predicted similarity: 0.11)
#   - Fincome (predicted similarity: 0.11)
#
# Recommended investors for the idea: 'A business that uses AI to train screenwriters how to integrate emotion into their stories using 85 unique techniques.'
#   - Alter Equity (predicted similarity: 0.12)
#   - Cool Climate Collective (predicted similarity: 0.11)
#   - Angels Bay Invest (predicted similarity: 0.11)
#   - StartCapital Partners (predicted similarity: 0.11)
#   - Compass Digital Ventures (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'An organizer system that you install in handbags to make it easier and faster to find things.'
#   - StartCapital Partners (predicted similarity: 0.10)
#   - Zen Ventures (predicted similarity: 0.10)
#   - Athenian VC (predicted similarity: 0.10)
#   - Synergy Ventures (predicted similarity: 0.10)
#   - Femmes Business Angels (predicted similarity: 0.09)
#
# Recommended investors for the idea: 'A lemonade stand outside event venues to sell to concert-goers'
#   - Sheesha Finance (predicted similarity: 0.15)
#   - American Prudential Capital, inc. (predicted similarity: 0.12)
#   - Lexi Ventures (predicted similarity: 0.10)
#   - HenQ Capital Partners (predicted similarity: 0.10)
#   - Merck Digital Sciences Studio (predicted similarity: 0.09)
#
# Recommended investors for the idea: 'A company that is measuring noise through consumers' mobile phones. '
#   - Alter Equity (predicted similarity: 0.12)
#   - Cool Climate Collective (predicted similarity: 0.11)
#   - American Prudential Capital, inc. (predicted similarity: 0.11)
#   - Hyundai CRADLE (predicted similarity: 0.11)
#   - Halogen Ventures (predicted similarity: 0.11)
#
# Recommended investors for the idea: 'A company that makes an app to stop food waste at home and helps people figure out recipes to make with the ingredients they already have.
# '
#   - Sheesha Finance (predicted similarity: 0.16)
#   - The Helm (predicted similarity: 0.13)
#   - Lexi Ventures (predicted similarity: 0.12)
#   - Halogen Ventures (predicted similarity: 0.12)
#   - Transition VC (predicted similarity: 0.12)
#
# Recommended investors for the idea: 'Mainstream air transportation with low carbon emissions '
#   - SyndicateRoom (predicted similarity: 0.09)
#   - Matchstick Ventures (predicted similarity: 0.08)
#   - Wildwood Ventures (predicted similarity: 0.08)
#   - Double River Impact (predicted similarity: 0.08)
#   - Prosto VC (predicted similarity: 0.07)
#
# Recommended investors for the idea: 'sharikat tasnae eilajat lilkilab khaliatan min alghulutin lilhayawanat almusabibat lilhasaasiati. Return all results in native Arabic
# '
#   - New Orleans BioInnovation Center (predicted similarity: 0.12)
#   - Staenberg Ventures (predicted similarity: 0.11)
#   - Zen Ventures (predicted similarity: 0.10)
#   - Vibe Bio (predicted similarity: 0.10)
#   - WXR Fund (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'A AIrbnb-like business that allows older people to rent their cars to generate additional income. '
#   - Alter Equity (predicted similarity: 0.12)
#   - Hyundai CRADLE (predicted similarity: 0.11)
#   - SaaStr Fund (predicted similarity: 0.10)
#   - Moneta Ventures (predicted similarity: 0.10)
#   - StartCapital Partners (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'une entreprise qui fabrique des friandises pour chiens sans gluten pour les animaux allergiques. Output all results in native French'
#   - Alpha Square Group (predicted similarity: 0.11)
#   - Northwestern Mutual Future Ventures (predicted similarity: 0.11)
#   - iFly.VC (predicted similarity: 0.11)
#   - Treble Capital (predicted similarity: 0.09)
#   - Synergy Ventures (predicted similarity: 0.09)
#
# Recommended investors for the idea: 'A business that does balloon animals for corporate events and concerts. '
#   - SaaStr Fund (predicted similarity: 0.11)
#   - Moneta Ventures (predicted similarity: 0.10)
#   - Biss Capital (predicted similarity: 0.10)
#   - Engineering Capital (predicted similarity: 0.10)
#   - Supply Change Capital (predicted similarity: 0.09)
#
# Recommended investors for the idea: 'A business that produces onion seeds in Guatemala looking to expand within the country. Return all results in native arabic'
#   - Alter Equity (predicted similarity: 0.12)
#   - Cool Climate Collective (predicted similarity: 0.12)
#   - Halogen Ventures (predicted similarity: 0.11)
#   - WXR Fund (predicted similarity: 0.10)
#   - HenQ Capital Partners (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'A software learning platform to upskill developers when they join new teams or a new technology is released into the market. Lots of the material will be crowdsourced from technology experts. '
#   - The Helm (predicted similarity: 0.13)
#   - Lexi Ventures (predicted similarity: 0.12)
#   - New Orleans BioInnovation Center (predicted similarity: 0.12)
#   - Kaya Ventures (predicted similarity: 0.11)
#   - Anthropocene Ventures (predicted similarity: 0.11)
#
# Recommended investors for the idea: 'A platform that connects startups and investors'
#   - Lexi Ventures (predicted similarity: 0.13)
#   - Hyundai CRADLE (predicted similarity: 0.13)
#   - New Orleans BioInnovation Center (predicted similarity: 0.13)
#   - Angels Bay Invest (predicted similarity: 0.13)
#   - American Prudential Capital, inc. (predicted similarity: 0.12)
#
# Recommended investors for the idea: 'A cross-border payment processor for money transfers.'
#   - Hoverink Venture Fund I, LP
#  (predicted similarity: 0.10)
#   - Evio.vc (predicted similarity: 0.10)
#   - Femmes Business Angels (predicted similarity: 0.10)
#   - 211 Mev Capital (predicted similarity: 0.09)
#   - Frontier Ventures (predicted similarity: 0.09)
#
# Recommended investors for the idea: ''
#   - Mercury Fund (predicted similarity: 0.13)
#   - Form Ventures (predicted similarity: 0.13)
#   - Studio Sia Partners (predicted similarity: 0.12)
#   - Strike Ventures (predicted similarity: 0.11)
#   - Marigold Capital (predicted similarity: 0.11)
#
# Recommended investors for the idea: 'Digital marketplace for electric vehicles to match homeowners and vehicles owners. It’s a combination between charging and parking. '
#   - Alter Equity (predicted similarity: 0.12)
#   - Hoverink Venture Fund I, LP
#  (predicted similarity: 0.10)
#   - iFly.VC (predicted similarity: 0.10)
#   - Engineering Capital (predicted similarity: 0.10)
#   - Moontide Capital (predicted similarity: 0.09)
#
# Recommended investors for the idea: 'How do I take a media company that has a following on social media and incorporate the latest trends to become a billion dollar company.  '
#   - Sheesha Finance (predicted similarity: 0.15)
#   - New Orleans BioInnovation Center (predicted similarity: 0.12)
#   - American Prudential Capital, inc. (predicted similarity: 0.12)
#   - Hyundai CRADLE (predicted similarity: 0.12)
#   - Lightship Capital (predicted similarity: 0.11)
#
# Recommended investors for the idea: 'A mems small satellite propulsion system for maneuvering satellites in space'
#   - Alter Equity (predicted similarity: 0.12)
#   - New Orleans BioInnovation Center (predicted similarity: 0.12)
#   - Lexi Ventures (predicted similarity: 0.11)
#   - Strada Education Network (predicted similarity: 0.10)
#   - Evio.vc (predicted similarity: 0.10)
#
# Recommended investors for the idea: 'a business for tourists that uses a QR code to pack and ship goods home via a mail service company so I don’t have to carry it home. '
#   - Sheesha Finance (predicted similarity: 0.15)
#   - The Helm (predicted similarity: 0.13)
#   - Alter Equity (predicted similarity: 0.12)
#   - Cool Climate Collective (predicted similarity: 0.12)
#   - American Prudential Capital, inc. (predicted similarity: 0.12)
#
# Recommended investors for the idea: 'BlockLenses are UV blocking daily-wear contact lenses that will solve light sensitivity issues without having to wear traditional sun-blocking eyewear for outdoor athletes who suffer from light-sensitive eyes but do not want to compromise their activity intensity.
# '
#   - American Prudential Capital, inc. (predicted similarity: 0.12)
#   - Avelana (predicted similarity: 0.12)
#   - WXR Fund (predicted similarity: 0.11)
#   - iSeed (predicted similarity: 0.10)
#   - Fincome (predicted similarity: 0.09)

# %%
from sklearn.cluster import MiniBatchKMeans

# Define number of clusters
n_clusters = 10

# Cluster investors and ideas
kmeans_investors = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
investors_clusters = kmeans_investors.fit_predict(investors_features_scaled)

kmeans_ideas = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
ideas_clusters = kmeans_ideas.fit_predict(ideas_features_scaled)

# Add cluster labels to DataFrames
investors_df['cluster'] = investors_clusters
ideas_df['cluster'] = ideas_clusters

# Recommend VCs within the same cluster as the idea
def recommend_vcs_within_cluster(idea_index, investors_df, ideas_df, n=5):
    idea_cluster = ideas_df.iloc[idea_index]['cluster']
    same_cluster_vcs = investors_df[investors_df['cluster'] == idea_cluster]
    
    # Rank VCs within the same cluster by similarity score
    similarities = cosine_similarities[idea_index, same_cluster_vcs.index]
    sorted_indices = np.argsort(similarities)[::-1][:n]
    return same_cluster_vcs.iloc[sorted_indices]['Investor name'].tolist()

# Example: Recommendations for the first idea
idea_index = 0
recommended_vcs = recommend_vcs_within_cluster(idea_index, investors_df, ideas_df, n=5)
print(f"Recommended VCs for idea '{ideas_df.iloc[idea_index]['idea_description']}':")
print(recommended_vcs)
# Out:
# Recommended VCs for idea 'An organizer system that you install in handbags to make it easier and faster to find things.':
# ['Physician Investor Alliance', 'Fintech Ventures Fund', 'Fitt Insider', 'Olive Capital', 'FirstCheck Africa']
